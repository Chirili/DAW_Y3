# %% [markdown]
# # Entrada y salida
# **Docente**: Antonio Gago.  **I.E.S. Velázquez:** Curso 2020-2021

# %% [markdown]
# ## Índice de contenidos
# * [1. Entrada y salida estándar](#sec_1)
#  * [1.1. Funciones input y print](#sec_1_1)
#  * [1.2. Formateo de cadenas](#sec_1_2)
# * [2. Lectura y escritura de ficheros](#sec_2)
#  * [2.1. Apertura y cierre de ficheros](#sec_2_1)
#  * [2.2. Lectura y escritura de texto libre](#sec_2_2)
#  * [2.3. Lectura y escritura de CSV](#sec_2_3)
#  * [2.4. Serialización y deserialización mediante JSON](#sec_2_4)

# %% [markdown]
# # 1. Entrada y salida estándar <a name="sec_1"/>

# %% [markdown]
# ## 1.1. Funciones input y print <a name="sec_1_1"/>

# %% [markdown]
# Por regla general, cuando ejecutamos un programa en Python llamamos **entrada estándar** al teclado de nuestro ordenador, y **salida estándar** a la pantalla. Como ya hemos visto, podemos leer datos desde el teclado mediante la función **input**, y escribir en la pantalla mediante la función **print**:

# %%
print("==== Cálculo de una potencia =====")
base = int(input("Introduzca un número entero (base):")) # La función predefinida input permite leer texto desde el teclado
exponente = int(input("Introduzca un número entero (exponente):"))

print("El resultado de", base, "elevado a", exponente, "es", base**exponente, '.')
# Out:
# ==== Cálculo de una potencia =====
# Introduzca un número entero (base):4
# Introduzca un número entero (exponente):3
# El resultado de 4 elevado a 3 es 64 .

# %% [markdown]
# La función **input** recibe opcionalmente un mensaje, que es mostrado al usuario para a continuación esperar que introduzca un texto. La ejecución del programa "se espera" en este punto, hasta que el usuario introduce el texto y pulsa la tecla *enter*. Entonces, **la función *input* devuelve el texto introducido por el usuario** (excluyendo la pulsación de la tecla *enter*, que no aparece en la cadena devuelta). Si en nuestro programa estábamos esperando un dato numérico, en lugar de una cadena, será necesario convertir la cadena al tipo deseado mediante alguna de las funciones de construcción de tipos que ya conocemos (por ejemplo, *int* para obtener un número entero o *float* para obtener un número real).
#
# Por su parte, la función **print** recibe una o varias expresiones por parámetros, y **muestra el resultado** de dichas expresiones en **pantalla**. Si el resultado de alguna de las expresiones es una cadena de texto, la muestra tal cual. Si el resultado de alguna de las expresiones es de cualquier otro tipo, la función *print* se encarga de convertir el resultado a cadena mediante el uso de la función *str*. Si recibe varias expresiones, por defecto *print* las muestra una tras otra, separadas por un espacio en blanco. Al finalizar de mostrar las expresiones, la ejecución de *print* finaliza imprimiendo un salto de línea; por consiguiente, la siguiente llamada a *print* escribirá en la siguiente línea de la pantalla. Ambas cosas, el carácter usado para separar las distintas expresiones y el carácter usado como finalizador, pueden cambiarse utilizando los parámetros opcionales adecuados:

# %%
import random
numeros = [random.randint(1, 100) for _ in range(10)]
print("Se han generado los siguientes números aleatorios: ")
for i, numero in enumerate(numeros):
    print(i, numero, sep=': ') # Se usa la cadena ': ' para separar las expresiones recibidas por print
# Out:
# Se han generado los siguientes números aleatorios:
# 0: 36
# 1: 13
# 2: 98
# 3: 54
# 4: 29
# 5: 97
# 6: 46
# 7: 85
# 8: 46
# 9: 38

# %%
texto = "Muestrame con guiones"
for caracter in texto:
    print('-' + caracter, end='') # Se indica a print que no concatene ninguna cadena al final del mensaje a mostrar
# Out:
# -M-u-e-s-t-r-a-m-e- -c-o-n- -g-u-i-o-n-e-s

# %% [markdown]
# Aunque el uso de los parámetro opcionales *sep* y *end* nos da algunas opciones para obtener la salida que deseamos en pantalla, a veces se nos puede quedar corto. Por ejemplo, si queremos mostrar un mensaje formado por distintos trozos de texto y datos a extraer de variables o expresiones, puede que no siempre queramos usar el mismo separador entre cada dos expresiones. Un ejemplo sencillo lo tenemos en la siguiente sentencia que ya hemos escrito antes:

# %%
print("El resultado de", base, "elevado a", exponente, "es", base**exponente, '.')

# %% [markdown]
# En este caso, nos interesa usar el espacio para separar los distintos trozos del mensaje a mostrar, salvo para el punto final, que debería aparecer a continuación del resultado de la expresión ``base**exponente``. Además, la forma en que las cadenas de texto y las expresiones se van intercalando en los parámetros del *print* complica un poco la legibilidad de la sentencia. Es por todo esto por lo que es apropiado usar el **formateo de cadenas** en estos casos.

# %% [markdown]
# ## 1.2. Formateo de cadenas <a name="sec_1_2"/>

# %% [markdown]
# El método **format** de las cadenas devuelve una versión *formateada* de la cadena. Entre otras cosas, nos permite intercalar en una cadena los resultados de diversas expresiones, eligiendo el orden o el formato en que se representan dichos resultados. Esta flexibilidad hace de *format* una función perfecta para ser utilizada junto a *print* para mostrar mensajes más o menos complejos, con mucho más control sobre la salida obtenida del que tendríamos usando únicamente *print*.
#
# El uso más básico de *format* consiste en intercalar en la cadena parejas de llaves, de manera que el método devolverá una cadena en la que se sustituirán las llaves por los resultados de evaluar las expresiones que reciba como parámetros, en el mismo orden:

# %%
a = int(input('Introduce un número:'))
b = int(input('Introduce un número:'))

print('El resultado de {} elevado a {} es {}.'.format(a, b, a**b))
# Out:
# Introduce un número:1
# Introduce un número:2
# El resultado de 1 elevado a 2 es 1.

# %% [markdown]
# Podemos hacer mención explícita entre las llaves a la expresión concreta que queremos intercalar. Para ello utilizamos números comenzando en cero (como si los parámetros recibidos por format fueran una lista):

# %%
 print('El resultado de {0} multiplicado por {1} es {2}'.format(a, b, a*b))
# Out:
# El resultado de 1 multiplicado por 2 es 2

# %% [markdown]
# Esto nos permite intercalar los datos en cualquier orden, o usarlos varias veces dentro de la cadena:

# %%
print('El resultado de {{ }} {0} entre {1} es {2}, y el de {1} entre {0} es {3}'.format(a, b, a/b, b/a))
# Out:
# El resultado de { } 1 entre 2 es 0.5, y el de 2 entre 1 es 2.0

# %% [markdown]
# Podemos formatear los valores numéricos, por ejemplo indicando que queremos redondear a 2 decimales. La f del siguiente ejemplo indica que el número a mostrar es un real:

# %%
print('El resultado de {0} entre {1} es {2:.2f}, y el de {1} entre {0} es {3}'.format(a, b, a/b, b/a))
# Out:
# El resultado de 1 entre 2 es 0.50, y el de 2 entre 1 es 2.0

# %% [markdown]
# También es posible conseguir que un dato ocupe un mínimo de caracteres, rellenando  los huecos con espacios si es necesario. Esto es especialmente útil cuando se desea mostrar información en forma de tabla, consiguiendo que las columnas queden alineadas. La d en el siguiente ejemplo indica que los números a mostrar son enteros:

# %%
print("Mostrando los cuadrados y los cubos de los números del 1 al 5:")
for i in range(1,6):
    print('{0} {1:2d} {2:3d}'.format(i, i*i, i*i*i))
# Out:
# Mostrando los cuadrados y los cubos de los números del 1 al 5:
# 1  1   1
# 2  4   8
# 3  9  27
# 4 16  64
# 5 25 125

# %% [markdown]
# Si lo preferimos, podemos rellenar los huecos con ceros en lugar de espacios, como se muestra en este ejemplo:

# %%
print("Mostrando los cuadrados y los cubos de los números del 1 al 5:")

for i in range(1,6):
    print('{0:03d} {1:03d} {2:03d}'.format(i, i*i, i*i*i))
    dd = '{0:03d} {1:03d} {2:03d}'.format(i, i*i, i*i*i)
print ("-----")
print (dd)
# Out:
# Mostrando los cuadrados y los cubos de los números del 1 al 5:
# 001 001 001
# 002 004 008
# 003 009 027
# 004 016 064
# 005 025 125
# -----
# 005 025 125

# %% [markdown]
# En ocasiones, nombrar a las distintas expresiones que pasamos al método format puede mejorar la legibilidad. Para ello, usaremos parámetros con nombre en la llamada a format, y podremos referirnos a dichos nombres en las distintas llaves que utilicemos en la cadena a formatear:

# %%
print('Si x es igual a {x} e y es igual a {y}, entonces la inecuación x < (y * 2) es {inecuacion}'.
             format(x=a, y=b, inecuacion= a<(b*2)))
# Out:
# Si x es igual a 1 e y es igual a 2, entonces la inecuación x < (y * 2) es True

# %% [markdown]
# # 2. Lectura y escritura de ficheros <a name="sec_2"/>

# %% [markdown]
# Muchas veces no es suficiente con la introducción de datos desde el teclado por parte del usuario. Es muy habitual leer datos desde un fichero o archivo (que llamamos de entrada). Igualmente, es posible escribir datos en un fichero (que llamamos de salida).
#
# Tanto la lectura como la escritura de datos en un fichero se puede realizar de diversas formas:
#
# * Mediante cadenas de texto libres, en lo que llamamos **ficheros de texto**.
# * Mediante cadenas de texto de un formato predefinido, como es el caso de los ficheros **csv**.
# * Mediante algún formato estándar de intercambio de datos (por ejemplo, **json**), lo que nos permite guardar y recuperar más tarde fácilmente el contenido de las variables de nuestros programas. A este tipo de escrituras y lecturas las llamamos *serialización* y *deserialización*, respectivamente.
# * Mediante datos binarios, en lo que llamamos *ficheros binarios*. De esta forma, el programador tiene el control absoluto de los datos que se escriben o se leen de un fichero. Esto no lo veremos en esta asignatura.

# %% [markdown]
# ## 2.1. Apertura y cierre de ficheros <a name="sec_2_1"/>
#
# Lo primero que hay que hacer para poder trabajar con un fichero es abrirlo. Al abrir un fichero, establecemos la manera en que vamos a trabajar con él: si lo haremos en modo texto o modo binario, o si vamos a leer o escribir de él, entre otras cosas.
#
# La apertura de un fichero se realiza mediante la función **open**:

# %%
f = open('fichero.txt')

# %% [markdown]
# Si la apertura del fichero se lleva a cabo sin problemas, la función nos devuelve un **descriptor del fichero**. Usaremos esta variable más adelante para leer o escribir en el fichero.
#
# Por defecto, el fichero se abre en modo texto para lectura. Podemos cambiar el modo en que se abre el fichero mediante el parámetro opcional **mode**, en el que pasaremos una cadena formada por alguno(s) de los caracteres siguientes:
# * 'r': abre el fichero en modo lectura.
# * 'w': abre el fichero en modo escritura. Si el archivo existía, lo sobrescribe (es decir, primero es borrado).
# * 'a': abre el fichero en modo escritura. Si el archivo existía, las escrituras se añadirán al final del fichero.
# * 't': abre el fichero en modo texto. Es el modo por defecto, así que normalmente no lo indicaremos y se entenderá que lo abrimos en modo texto. Es el modo que usaremos siempre en nuestra asignatura.
# * 'b': abre el fichero en modo binario.
#
# Veamos como ejemplo cómo abrir un fichero de texto para escribir en él, sobrescribiéndolo si ya existía:

# %%
f2 = open('fichero_escritura.txt', mode='w')

# %% [markdown]
# Cuando abrimos un fichero de texto es importante que tengamos en cuenta la **codificación de caracteres** utilizada por el fichero. Existen diversos estándares, aunque el más utilizado hoy en día en el contexto de Internet es el **utf-8**. Será éste el que usaremos preferiblemente. Por defecto, la función *open* decide la codificación de caracteres en función de la configuración de nuestro sistema operativo. Para especificar explícitamente que se utilice *utf-8* lo haremos mediantes el parámetro opcional **encoding**:

# %%
f3 = open('fichero.txt', encoding='utf-8')

# %% [markdown]
# Cuando terminemos de trabajar con el fichero (por ejemplo, al acabar de leer su contenido), es importante **cerrarlo**. De esta forma liberamos el recurso para que puedan trabajar con él otros procesos de nuestra máquina, y también nos aseguramos de que las escrituras que hayamos realizado se llevan a cabo de manera efectiva en disco (ya que las escrituras suelen utilizar un buffer en memoria para mejorar la eficiencia). Para cerrar un fichero usamos el método **close** sobre el descriptor del fichero que queremos cerrar:

# %%
f.close()
f2.close()
f3.close()

# %% [markdown]
# Una forma de no olvidarnos de cerrar el fichero (algo muy habitual) es usar la sentencia **with**:

# %%
with open('fichero.txt', encoding='utf-8') as f:
    print('Trabajamos con el fichero...')

# %% [markdown]
# Una vez ejecutadas las instrucciones contenidas en el bloque *with*, el fichero es cerrado automáticamente. Esta variante tiene la ventaja además de que si se produce cualquier error mientras trabajamos con el fichero, que produzca la parada de la ejecución de nuestro programa, el fichero también es cerrado. Esto no ocurre si abrimos el fichero sin usar *with*.

# %% [markdown]
# ## 2.2. Lectura y escritura de texto libre <a name="sec_2_2"/>

# %% [markdown]
# Una vez abierto un fichero en modo texto, podemos leer todo el contenido y guardarlo en una variable de tipo cadena mediante el método **read**:

# %%
with open('fichero.txt', encoding='utf-8') as f:
    contenido = f.read()
    print(contenido)  # Mostramos el contenido del fichero

# %% [markdown]
# Aunque se puede hacer de esta forma, es más habitual leer los ficheros de texto línea a línea. De esta forma podemos procesar archivos muy grandes sin usar demasiada memoria. Para ello, podemos usar el descriptor del fichero dentro de un bucle *for*, como si se tratara de una secuencia de cadenas, de manera que en cada paso del bucle obtendremos la siguiente línea del fichero:

# %%
with open('fichero.txt', encoding='utf-8') as f:
    for linea in f:
        print(linea)

# %% [markdown]
# Observarás que en el ejemplo anterior se está visualizando cada línea separada con una línea vacía. Esto es así porque la línea leida del fichero incluye al final un salto de línea, y a su vez la función *print* incluye un salto de línea tras la cadena a mostrar. Si queremos mostrar el contenido del fichero con el mismo formato que en el ejemplo anterior, podríamos hacer esto:

# %%
with open('fichero.txt', encoding='utf-8') as f:
    for linea in f:
        print(linea, end='')

# %% [markdown]
# Para escribir texto en un fichero, usaremos el método **write** sobre el descriptor del fichero:

# %%
with open('./ejemplo/fichero_escritura.txt', mode='w', encoding='utf-8') as f:
    f.write('Este texto se almacenará en el fichero.')

# %% [markdown]
# Comprobemos si se ha realizado la escritura correctamente:

# %%
with open('./ejemplo/fichero_escritura.txt', encoding='utf-8') as f:
    contenido = f.read()
    print(contenido)

# %% [markdown]
# ## 2.3. Lectura y escritura de CSV <a name="sec_2_3"/>

# %% [markdown]
# Un tipo de fichero de texto que suele usarse es el llamado formato **CSV** (por *Comma-Separated Values*). Estos ficheros se utilizan para almacenar datos de tipo tabular, al estilo de una hoja de cálculo. En este notebook se incluye un fichero con este formato, extraído del "Servicio de alquiler de bicicletas públicas de Sevilla (Sevici)". Veamos un trozo de su contenido:

# %%
with open('estaciones.csv', encoding='utf-8') as f:
    # Leemos las líneas del fichero junto con un número que indica la línea por la que vamos
    for num_linea, linea in enumerate(f):  
        print(linea, end='')
        if num_linea == 10:   # Al llegar a las 10 líneas, paramos
            break
# Out:
# name,slots,empty_slots,free_bikes,latitude,longitude
# 149_CALLE ARROYO,20,11,9,37.397829929383,-5.97567172039552
# 257_TORRES ALBARRACIN,20,16,4,37.38376948792722,-5.908921914235877
# 243_GLORIETA DEL PRIMERO DE MAYO,15,6,9,37.380439481169994,-5.953481197462845
# 109_AVENIDA SAN FRANCISCO JAVIER,15,1,14,37.37988413609134,-5.974382770011586
# 073_PLAZA SAN AGUSTIN,15,10,4,37.38951386231434,-5.984362789545622
# 096_CALLE BETIS,19,17,2,37.3835407311529,-5.999910722822249
# 256_MIGUEL MONTORO,29,27,1,37.386100496778624,-5.910090919676698
# 082_CALLE LUIS MONTOTO,17,12,5,37.387098477016366,-5.974843147214583
# 226_AVENIDA DOCTOR EMILIO LEMOS,15,10,5,37.402862871745285,-5.921753676327738
# 103_AVENIDA EDUARDO DATO,20,20,0,37.384432463478554,-5.982738173371375

# %% [markdown]
# Como puedes observar, los datos vienen expresados por columnas. Cada columna o atributo representa un dato concreto, y cada línea representa una tupla o registro de valores para cada uno de los atributos.
#
# Para poder trabajar con estos datos, lo normal es que necesitemos acceder a cada atributo de cada registro por separado. Si leemos el fichero línea a línea, podríamos acceder a cada atributo si rompemos la cadena en cada uno de los trozos separados por una coma. Esto puede conseguirse así:

# %%
with open('estaciones.csv', encoding='utf-8') as f:
    for num_linea, linea in enumerate(f):  
        trozos = linea.split(',')
        print(trozos)
        if num_linea == 10:   # Al llegar a las 10 líneas, paramos
            break
# Out:
# ['name', 'slots', 'empty_slots', 'free_bikes', 'latitude', 'longitude\n']
# ['149_CALLE ARROYO', '20', '11', '9', '37.397829929383', '-5.97567172039552\n']
# ['257_TORRES ALBARRACIN', '20', '16', '4', '37.38376948792722', '-5.908921914235877\n']
# ['243_GLORIETA DEL PRIMERO DE MAYO', '15', '6', '9', '37.380439481169994', '-5.953481197462845\n']
# ['109_AVENIDA SAN FRANCISCO JAVIER', '15', '1', '14', '37.37988413609134', '-5.974382770011586\n']
# ['073_PLAZA SAN AGUSTIN', '15', '10', '4', '37.38951386231434', '-5.984362789545622\n']
# ['096_CALLE BETIS', '19', '17', '2', '37.3835407311529', '-5.999910722822249\n']
# ['256_MIGUEL MONTORO', '29', '27', '1', '37.386100496778624', '-5.910090919676698\n']
# ['082_CALLE LUIS MONTOTO', '17', '12', '5', '37.387098477016366', '-5.974843147214583\n']
# ['226_AVENIDA DOCTOR EMILIO LEMOS', '15', '10', '5', '37.402862871745285', '-5.921753676327738\n']
# ['103_AVENIDA EDUARDO DATO', '20', '20', '0', '37.384432463478554', '-5.982738173371375\n']

# %% [markdown]
# Como puedes observar, al usar el método *split* obtenemos una lista con los distintos atributos de cada línea. Podríamos acceder ahora al atributo que quisiéramos usando los corchetes sobre dicha lista.
#
# Sin embargo, esta no es la mejor manera de trabajar con un CSV, ya que se nos pueden colar espacios en blanco en sitios que no esperamos, caracteres de salto de línea... Existen en Python dos mecanismos que nos permiten leer CSV de una forma más sencilla y robusta:
# * Mediante la función **csv.reader**, que nos permite recorrer cada registro del fichero en formato lista.
# * Mediante el objeto **csv.DictReader**, que nos permite recorrer cada registro del fichero en formato diccionario.
#
# Empecemos viendo un ejemplo de uso de **csv.reader**:

# %%
import csv # Hay que importar el paquete csv

with open('estaciones.csv', encoding='utf-8') as f:
    lector = csv.reader(f)
    for registro in lector:
        print(registro)
        # Para este ejemplo, nos basta con ver el primer registro
        break;
# Out:
# ['name', 'slots', 'empty_slots', 'free_bikes', 'latitude', 'longitude']

# %% [markdown]
# En el CSV que estamos procesando, la primera línea contiene los nombres de los atributos. No es por tanto un registro como tal (no contiene valores), por lo que lo habitual es saltárnoslo. Esto se puede conseguir de la siguiente forma:

# %%
with open('estaciones.csv', encoding='utf-8') as f:
    lector = csv.reader(f)
    next(lector) # Nos saltamos la cabecera del CSV
    for registro in lector:
        print(registro)
        # Para este ejemplo, nos basta con ver el primer registro
        break;
# Out:
# ['149_CALLE ARROYO', '20', '11', '9', '37.397829929383', '-5.97567172039552']

# %% [markdown]
# Normalmente, nos interesa almacenar los registros en alguna estructura de datos, para utilizarlos más adelante en nuestro programa. Podemos utilizar por ejemplo una lista para almacenar cada registro. Además, es conveniente que convirtamos cada atributo al tipo de datos de Python que mejor se adapte al tipo de dato que representa el atributo. En nuestro ejemplo, el primer atributo es una cadena de texto, los tres siguientes son números enteros, y los dos últimos números reales.
#
# Podríamos obtener una lista de tuplas, cada tupla representando un registro del fichero, de esta manera:

# %%
with open('estaciones.csv', encoding='utf-8') as f:
    lector = csv.reader(f)
    next(lector) # Nos saltamos la cabecera del CSV
    registros = []
    for registro in lector:
        name = registro[0]
        slots = int(registro[1])
        empty_slots = int(registro[2])
        free_bikes = int(registro[3])
        latitude = float(registro[4])
        longitude = float(registro[5])
        tupla = (name, slots, empty_slots, free_bikes, latitude, longitude)
        registros.append(tupla)

# Mostremos los 10 primeros registros
print(registros[:10])
# Out:
# [('149_CALLE ARROYO', 20, 11, 9, 37.397829929383, -5.97567172039552), ('257_TORRES ALBARRACIN', 20, 16, 4, 37.38376948792722, -5.908921914235877), ('243_GLORIETA DEL PRIMERO DE MAYO', 15, 6, 9, 37.380439481169994, -5.953481197462845), ('109_AVENIDA SAN FRANCISCO JAVIER', 15, 1, 14, 37.37988413609134, -5.974382770011586), ('073_PLAZA SAN AGUSTIN', 15, 10, 4, 37.38951386231434, -5.984362789545622), ('096_CALLE BETIS', 19, 17, 2, 37.3835407311529, -5.999910722822249), ('256_MIGUEL MONTORO', 29, 27, 1, 37.386100496778624, -5.910090919676698), ('082_CALLE LUIS MONTOTO', 17, 12, 5, 37.387098477016366, -5.974843147214583), ('226_AVENIDA DOCTOR EMILIO LEMOS', 15, 10, 5, 37.402862871745285, -5.921753676327738), ('103_AVENIDA EDUARDO DATO', 20, 20, 0, 37.384432463478554, -5.982738173371375)]

# %% [markdown]
# Si tenemos muchos atributos, es preferible utilizar **csv.DictReader** para leer el CSV. La diferencia con *csv.reader* es que cada registro devuelto está representado mediante un diccionario, en el que las claves son los nombres de los atributos (obtenidos a partir de la cabecera del CSV) y los valores asociados son los valores de los atributos correspondientes. Al hacer uso de los nombres de los atributos para acceder a los atributos se mejora la legibilidad del código:

# %%
with open('estaciones.csv', encoding='utf-8') as f:
    lector = csv.DictReader(f)
    registros = []
    for registro in lector:
        registros.append(registro)

# Mostremos los 10 primeros registros
print(registros[:10])
# Out:
# [{'name': '149_CALLE ARROYO', 'slots': '20', 'empty_slots': '11', 'free_bikes': '9', 'latitude': '37.397829929383', 'longitude': '-5.97567172039552'}, {'name': '257_TORRES ALBARRACIN', 'slots': '20', 'empty_slots': '16', 'free_bikes': '4', 'latitude': '37.38376948792722', 'longitude': '-5.908921914235877'}, {'name': '243_GLORIETA DEL PRIMERO DE MAYO', 'slots': '15', 'empty_slots': '6', 'free_bikes': '9', 'latitude': '37.380439481169994', 'longitude': '-5.953481197462845'}, {'name': '109_AVENIDA SAN FRANCISCO JAVIER', 'slots': '15', 'empty_slots': '1', 'free_bikes': '14', 'latitude': '37.37988413609134', 'longitude': '-5.974382770011586'}, {'name': '073_PLAZA SAN AGUSTIN', 'slots': '15', 'empty_slots': '10', 'free_bikes': '4', 'latitude': '37.38951386231434', 'longitude': '-5.984362789545622'}, {'name': '096_CALLE BETIS', 'slots': '19', 'empty_slots': '17', 'free_bikes': '2', 'latitude': '37.3835407311529', 'longitude': '-5.999910722822249'}, {'name': '256_MIGUEL MONTORO', 'slots': '29', 'empty_slots': '27', 'free_bikes': '1', 'latitude': '37.386100496778624', 'longitude': '-5.910090919676698'}, {'name': '082_CALLE LUIS MONTOTO', 'slots': '17', 'empty_slots': '12', 'free_bikes': '5', 'latitude': '37.387098477016366', 'longitude': '-5.974843147214583'}, {'name': '226_AVENIDA DOCTOR EMILIO LEMOS', 'slots': '15', 'empty_slots': '10', 'free_bikes': '5', 'latitude': '37.402862871745285', 'longitude': '-5.921753676327738'}, {'name': '103_AVENIDA EDUARDO DATO', 'slots': '20', 'empty_slots': '20', 'free_bikes': '0', 'latitude': '37.384432463478554', 'longitude': '-5.982738173371375'}]

# %% [markdown]
# Si el CSV que utilizamos no tiene una primera línea de cabecera con los nombres de los atributos, podemos pasarle dichos nombres a *csv.DictReader* mediante el parámetro opcional **fieldnames**. Debemos pasar en dicho parámetro una lista de cadenas con los nombres que queremos asignarle a los atributos, en el mismo orden en que aparezcan en el CSV.

# %% [markdown]
# ### ¡Prueba tú!

# %%
# Personaliza las claves del diccionario obtenido con DictReader de forma que sean las traducciones de los atributos
with open('estaciones.csv', encoding='utf-8') as f:
    nombres = ["nombre","slots","vacios","libres","latitud","longitud"]
    lector = csv.DictReader(f, fieldnames=nombres)
    print(lector)
    registros = []
    for registro in lector:
        print(registro)
        registros.append(registro)

# Mostremos los 10 primeros registros
print(registros[:10])
# Out:
# <csv.DictReader object at 0x000001D9B523A040>
# {'nombre': 'name', 'slots': 'slots', 'vacios': 'empty_slots', 'libres': 'free_bikes', 'latitud': 'latitude', 'longitud': 'longitude'}
# {'nombre': '149_CALLE ARROYO', 'slots': '20', 'vacios': '11', 'libres': '9', 'latitud': '37.397829929383', 'longitud': '-5.97567172039552'}
# {'nombre': '257_TORRES ALBARRACIN', 'slots': '20', 'vacios': '16', 'libres': '4', 'latitud': '37.38376948792722', 'longitud': '-5.908921914235877'}
# {'nombre': '243_GLORIETA DEL PRIMERO DE MAYO', 'slots': '15', 'vacios': '6', 'libres': '9', 'latitud': '37.380439481169994', 'longitud': '-5.953481197462845'}
# {'nombre': '109_AVENIDA SAN FRANCISCO JAVIER', 'slots': '15', 'vacios': '1', 'libres': '14', 'latitud': '37.37988413609134', 'longitud': '-5.974382770011586'}
# {'nombre': '073_PLAZA SAN AGUSTIN', 'slots': '15', 'vacios': '10', 'libres': '4', 'latitud': '37.38951386231434', 'longitud': '-5.984362789545622'}
# {'nombre': '096_CALLE BETIS', 'slots': '19', 'vacios': '17', 'libres': '2', 'latitud': '37.3835407311529', 'longitud': '-5.999910722822249'}
# {'nombre': '256_MIGUEL MONTORO', 'slots': '29', 'vacios': '27', 'libres': '1', 'latitud': '37.386100496778624', 'longitud': '-5.910090919676698'}
# {'nombre': '082_CALLE LUIS MONTOTO', 'slots': '17', 'vacios': '12', 'libres': '5', 'latitud': '37.387098477016366', 'longitud': '-5.974843147214583'}
# {'nombre': '226_AVENIDA DOCTOR EMILIO LEMOS', 'slots': '15', 'vacios': '10', 'libres': '5', 'latitud': '37.402862871745285', 'longitud': '-5.921753676327738'}
# {'nombre': '103_AVENIDA EDUARDO DATO', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.384432463478554', 'longitud': '-5.982738173371375'}
# {'nombre': '016_CALLE DE MANUEL VILLALOBOS', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.40705079945115', 'longitud': '-5.982430505819379'}
# {'nombre': '209_AVENIDA ALEMANIA', 'slots': '15', 'vacios': '3', 'libres': '11', 'latitud': '37.34531731164308', 'longitud': '-5.982656150368391'}
# {'nombre': '026_AVENIDA DE MIRAFLORES', 'slots': '17', 'vacios': '16', 'libres': '1', 'latitud': '37.40249453741322', 'longitud': '-5.977678166024575'}
# {'nombre': '221_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '15', 'vacios': '11', 'libres': '3', 'latitud': '37.40560856297865', 'longitud': '-5.930524002164018'}
# {'nombre': '128_VIRGEN DE LORETO', 'slots': '18', 'vacios': '6', 'libres': '12', 'latitud': '37.37645342505249', 'longitud': '-6.000632231559362'}
# {'nombre': '077_PLAZA CHAPINA', 'slots': '20', 'vacios': '13', 'libres': '7', 'latitud': '37.389629475123165', 'longitud': '-6.007581263540937'}
# {'nombre': '087_PLAZA NUEVA', 'slots': '40', 'vacios': '5', 'libres': '35', 'latitud': '37.38896647697466', 'longitud': '-5.995294220038549'}
# {'nombre': '036_CALLE SAN VICENTE', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.40050052188098', 'longitud': '-5.998403237581298'}
# {'nombre': '220_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '30', 'vacios': '18', 'libres': '11', 'latitud': '37.40518956185269', 'longitud': '-5.935780020616404'}
# {'nombre': '154_AVENIDA KANSAS CITY', 'slots': '20', 'vacios': '12', 'libres': '8', 'latitud': '37.394836510246314', 'longitud': '-5.96842612917054'}
# {'nombre': '024_CALLE LEÓN XIII', 'slots': '15', 'vacios': '10', 'libres': '5', 'latitud': '37.404035541034794', 'longitud': '-5.984592191160378'}
# {'nombre': '195_CALLE CORRAL DEL AGUA', 'slots': '20', 'vacios': '5', 'libres': '15', 'latitud': '37.42171561628419', 'longitud': '-5.971648155914519'}
# {'nombre': '169_AVENIDA RAMÓN Y CAJAL', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.37650143552164', 'longitud': '-5.972667133462907'}
# {'nombre': '211_AVENIDA DE ALEMANIA', 'slots': '15', 'vacios': '8', 'libres': '6', 'latitud': '37.34620231070945', 'longitud': '-5.976200128537064'}
# {'nombre': '125_AVENIDA SAN FRANCISCO JAVIER', 'slots': '15', 'vacios': '1', 'libres': '14', 'latitud': '37.377406438312754', 'longitud': '-5.974900141818838'}
# {'nombre': '148_CALLE THARSIS', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.39876767567268', 'longitud': '-5.973182395926595'}
# {'nombre': '122_CALLE ENRAMADILLA', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.37848444133301', 'longitud': '-5.978389154681133'}
# {'nombre': '192_AVENIDA DE ALVAR NUÑEZ', 'slots': '19', 'vacios': '19', 'libres': '0', 'latitud': '37.37833442855656', 'longitud': '-6.011556270990402'}
# {'nombre': '101_PRADO DE SAN SEBASTIAN', 'slots': '40', 'vacios': '18', 'libres': '22', 'latitud': '37.38111568185353', 'longitud': '-5.986949751279455'}
# {'nombre': '246_PUERTO DE LOS AZORES', 'slots': '15', 'vacios': '7', 'libres': '6', 'latitud': '37.376139062455664', 'longitud': '-5.955017317014327'}
# {'nombre': '173_RONDA TAMARGUILLO', 'slots': '20', 'vacios': '11', 'libres': '7', 'latitud': '37.370048411458974', 'longitud': '-5.968064113583803'}
# {'nombre': '171_CALLE ALFONSO LASO DE LA VEGA', 'slots': '19', 'vacios': '4', 'libres': '13', 'latitud': '37.36614639337372', 'longitud': '-5.974870135199807'}
# {'nombre': '059_AVENIDA DE LA PALMERA', 'slots': '18', 'vacios': '10', 'libres': '7', 'latitud': '37.37123840842449', 'longitud': '-5.989210188461531'}
# {'nombre': '194_CALLE PARQUE DE DOÑANA', 'slots': '20', 'vacios': '10', 'libres': '10', 'latitud': '37.418732603824466', 'longitud': '-5.97319415962488'}
# {'nombre': '186_CALLE ORFEBRE DOMINGUEZ VÁZQUEZ', 'slots': '20', 'vacios': '13', 'libres': '6', 'latitud': '37.40860456343952', 'longitud': '-5.973161153696026'}
# {'nombre': '100_PASEO CATALINA RIBERA', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.381516148333745', 'longitud': '-5.98899864813969'}
# {'nombre': '132_CALLE PAEZ DE RIVERA', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.36361937962884', 'longitud': '-5.984785168525709'}
# {'nombre': '202_AVENIDA MUJER TRABAJADORA', 'slots': '20', 'vacios': '19', 'libres': '0', 'latitud': '37.41146657719195', 'longitud': '-5.966763132907271'}
# {'nombre': '143_CALLE RAMON DE CARRANZA', 'slots': '18', 'vacios': '15', 'libres': '1', 'latitud': '37.37172440518047', 'longitud': '-6.00331223823691'}
# {'nombre': '046_PLAZA DEL PELICANO', 'slots': '16', 'vacios': '16', 'libres': '0', 'latitud': '37.397593515590735', 'longitud': '-5.983873184934495'}
# {'nombre': '255_PERO MINGO', 'slots': '30', 'vacios': '29', 'libres': '0', 'latitud': '37.385659308608595', 'longitud': '-5.913451790889467'}
# {'nombre': '119_AVENIDA DE CHILE', 'slots': '20', 'vacios': '14', 'libres': '6', 'latitud': '37.37740443203299', 'longitud': '-5.991965201690994'}
# {'nombre': '033_CALLE LEÓN XIII', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.401460531089214', 'longitud': '-5.983690186516563'}
# {'nombre': '200_CAMINO DE LOS TOROS', 'slots': '20', 'vacios': '2', 'libres': '18', 'latitud': '37.41891360818369', 'longitud': '-5.963217124751443'}
# {'nombre': '249_CALLE NAVARRA', 'slots': '15', 'vacios': '4', 'libres': '11', 'latitud': '37.42475843174024', 'longitud': '-5.984823673360926'}
# {'nombre': '188_AVENIDA HYTASA', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.37256042361221', 'longitud': '-5.963362098447178'}
# {'nombre': '021_CALLE MANUEL VILLALOBOS', 'slots': '20', 'vacios': '5', 'libres': '15', 'latitud': '37.405473547892335', 'longitud': '-5.981527181236149'}
# {'nombre': '038_CALLE DE INCA GARCILASO', 'slots': '40', 'vacios': '19', 'libres': '19', 'latitud': '37.3920814836453', 'longitud': '-6.011051277130786'}
# {'nombre': '012_PLAZA DUQUESA DE ALBA', 'slots': '30', 'vacios': '27', 'libres': '3', 'latitud': '37.403869536605576', 'longitud': '-5.994904227249628'}
# {'nombre': '241_PLAZA NUEVA', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.38881544328257', 'longitud': '-5.995863788052556'}
# {'nombre': '208_AVENIDA DE GRECIA', 'slots': '15', 'vacios': '1', 'libres': '13', 'latitud': '37.35065632807553', 'longitud': '-5.984190158922543'}
# {'nombre': '168_AVENIDA RAMÓN Y CAJAL', 'slots': '18', 'vacios': '17', 'libres': '1', 'latitud': '37.37505743166244', 'longitud': '-5.967492114476132'}
# {'nombre': '206_AVENIDA KANSAS CITY', 'slots': '15', 'vacios': '11', 'libres': '4', 'latitud': '37.402963548427635', 'longitud': '-5.958211097806437'}
# {'nombre': '066_CALLE ARROYO', 'slots': '20', 'vacios': '3', 'libres': '17', 'latitud': '37.39362550048881', 'longitud': '-5.981869175620968'}
# {'nombre': '061_PLAZA DEL MUSEO', 'slots': '20', 'vacios': '7', 'libres': '13', 'latitud': '37.392813490850365', 'longitud': '-5.999344236464369'}
# {'nombre': '041_PLAZA CALDERÓN DE LA BARCA', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.39958252091155', 'longitud': '-5.991029211181825'}
# {'nombre': '058_CALLE REGINA', 'slots': '19', 'vacios': '17', 'libres': '1', 'latitud': '37.39436722277961', 'longitud': '-5.991544993040244'}
# {'nombre': '118_PLAZA DE CUBA', 'slots': '20', 'vacios': '12', 'libres': '8', 'latitud': '37.379791416292186', 'longitud': '-5.997107796424417'}
# {'nombre': '067_CALLE LEONARDO DA VINCI', 'slots': '20', 'vacios': '2', 'libres': '18', 'latitud': '37.404162533250535', 'longitud': '-6.00730227091074'}
# {'nombre': '207_CALLE IFNI', 'slots': '20', 'vacios': '3', 'libres': '15', 'latitud': '37.35501634616241', 'longitud': '-5.982370155065175'}
# {'nombre': '102_CALLE JUAN DE MATA CARRIAZO', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.38273945636004', 'longitud': '-5.983720175839885'}
# {'nombre': '014_AVENIDA SANCHEZ PIZJUAN', 'slots': '40', 'vacios': '19', 'libres': '21', 'latitud': '37.4064737057759', 'longitud': '-5.989118739088445'}
# {'nombre': '232_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '15', 'vacios': '4', 'libres': '11', 'latitud': '37.40393955876748', 'longitud': '-5.939739033438785'}
# {'nombre': '167_GLORIETA BIZCO AMATE', 'slots': '20', 'vacios': '4', 'libres': '16', 'latitud': '37.37334966832237', 'longitud': '-5.964933613203329'}
# {'nombre': '253_HOSPITAL VALME', 'slots': '30', 'vacios': '18', 'libres': '12', 'latitud': '37.320417860390016', 'longitud': '-5.96902252657327'}
# {'nombre': '079_PLAZA DE LAS MERCEDARIAS', 'slots': '10', 'vacios': '9', 'libres': '1', 'latitud': '37.388326477494125', 'longitud': '-5.98690419023187'}
# {'nombre': '227_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '12', 'vacios': '9', 'libres': '3', 'latitud': '37.39075351415996', 'longitud': '-5.91963595581283'}
# {'nombre': '090_CALLE ROMA', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.381198446608074', 'longitud': '-5.993528209364882'}
# {'nombre': '224_AVENIDA DE LAS CIENCIAS', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.397013539467245', 'longitud': '-5.923756974136509'}
# {'nombre': '117_AVDA ESPERANZA DE TRIANA', 'slots': '14', 'vacios': '6', 'libres': '7', 'latitud': '37.377806429728786', 'longitud': '-6.002613239293098'}
# {'nombre': '123_ESTADIO OLIMPICO', 'slots': '20', 'vacios': '8', 'libres': '12', 'latitud': '37.41585058006381', 'longitud': '-6.005474271334001'}
# {'nombre': '258_ESTACA DE VARES', 'slots': '17', 'vacios': '12', 'libres': '5', 'latitud': '37.38369648551305', 'longitud': '-5.914819934855601'}
# {'nombre': '142_CALLE RAMON DE CARRANZA', 'slots': '18', 'vacios': '15', 'libres': '2', 'latitud': '37.371651407131054', 'longitud': '-5.997212216783402'}
# {'nombre': '051_AVENIDA TORNEO', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.395519500564795', 'longitud': '-6.002321248467498'}
# {'nombre': '251_AVDA. CRUZ CAMPO', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.384349424571234', 'longitud': '-5.965378365247481'}
# {'nombre': '043_RONDA CAPUCHINOS', 'slots': '15', 'vacios': '10', 'libres': '5', 'latitud': '37.399156087435365', 'longitud': '-5.982736630025496'}
# {'nombre': '237_CIUDAD DE CHIVA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.409334585727706', 'longitud': '-5.923254979770833'}
# {'nombre': '011_ALBERTO JIMÉNEZ BECERRIL', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.4071428838914', 'longitud': '-5.99259029973418'}
# {'nombre': '196_CALLE ESTRELLA CANOPUS', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.42470162875488', 'longitud': '-5.970101152202059'}
# {'nombre': '062_PLAZA DE ARMAS', 'slots': '39', 'vacios': '22', 'libres': '17', 'latitud': '37.391061482462725', 'longitud': '-6.003150248813141'}
# {'nombre': '216_CALLE ANTIOQUIA', 'slots': '15', 'vacios': '13', 'libres': '1', 'latitud': '37.39993753083735', 'longitud': '-5.95628508908707'}
# {'nombre': '248_GLORIETA DE LOS FERROVIARIOS', 'slots': '15', 'vacios': '0', 'libres': '12', 'latitud': '37.421903023693936', 'longitud': '-5.983004288085699'}
# {'nombre': '080_CALLE LUIS MONTOTO', 'slots': '20', 'vacios': '17', 'libres': '2', 'latitud': '37.3876274768589', 'longitud': '-5.98102716921146'}
# {'nombre': '184_AVENIDA ALCALDE MANUEL DEL VALLE', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.408524564095075', 'longitud': '-5.97049314429485'}
# {'nombre': '133_AVENIDA SANTA FE', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.37403941410158', 'longitud': '-6.004198242683363'}
# {'nombre': '187_CALLE DOCTOR LAFFON', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.39540051410288', 'longitud': '-5.964043114126317'}
# {'nombre': '165_AVENIDA DE ANDALUCIA', 'slots': '20', 'vacios': '19', 'libres': '1', 'latitud': '37.38764548429808', 'longitud': '-5.96095309881845'}
# {'nombre': '259_OCHO DE MARZO', 'slots': '30', 'vacios': '25', 'libres': '5', 'latitud': '37.36731840562508', 'longitud': '-5.954117063090828'}
# {'nombre': '106_AVENIDA EDUARDO DATO', 'slots': '15', 'vacios': '14', 'libres': '1', 'latitud': '37.383797462883464', 'longitud': '-5.977454154468565'}
# {'nombre': '022_AVENIDA DE LLANES', 'slots': '20', 'vacios': '4', 'libres': '16', 'latitud': '37.40512954896668', 'longitud': '-5.974831157557763'}
# {'nombre': '097_PASEO DE CRISTÓBAL COLÓN', 'slots': '20', 'vacios': '10', 'libres': '10', 'latitud': '37.381535447210965', 'longitud': '-5.995552216661944'}
# {'nombre': '081_CALLE LUIS MONTOTO', 'slots': '15', 'vacios': '13', 'libres': '1', 'latitud': '37.387156202671285', 'longitud': '-5.971016767894659'}
# {'nombre': '234_CALLE MÉDICOS SIN FRONTERA', 'slots': '14', 'vacios': '14', 'libres': '0', 'latitud': '37.3999401269442', 'longitud': '-5.925163964339344'}
# {'nombre': '235_CIUDAD DE CHIVA', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.411735810991', 'longitud': '-5.929859071297002'}
# {'nombre': '213_AVENIDA DE ANDALUCIA', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.38714348690405', 'longitud': '-5.948410054553437'}
# {'nombre': '160_PASEO CRISTOBAL COLON', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.387178', 'longitud': '-6.001376'}
# {'nombre': '244_AVENIDA LOS GAVILANES', 'slots': '15', 'vacios': '5', 'libres': '9', 'latitud': '37.3780400290467', 'longitud': '-5.95178368562984'}
# {'nombre': '190_AVENIDA HYTASA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.36873540997663', 'longitud': '-5.957293074803896'}
# {'nombre': '247_AVDA. RAMON Y CAJAL', 'slots': '30', 'vacios': '0', 'libres': '29', 'latitud': '37.37823143994186', 'longitud': '-5.979362157954825'}
# {'nombre': '141_CALLE FELIPE II', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.37173344957564', 'longitud': '-5.981895354240737'}
# {'nombre': '242_PLAZA NUEVA', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.38881830392981', 'longitud': '-5.995750976296489'}
# {'nombre': '027_AVENIDA DE LLANES', 'slots': '17', 'vacios': '16', 'libres': '1', 'latitud': '37.403877544974165', 'longitud': '-5.972090147223454'}
# {'nombre': '001_GLORIETA OLIMPICA', 'slots': '20', 'vacios': '19', 'libres': '1', 'latitud': '37.4129235511391', 'longitud': '-5.98890593824315'}
# {'nombre': '217_CALLE DE LA A.D.A.', 'slots': '15', 'vacios': '4', 'libres': '11', 'latitud': '37.393874505420214', 'longitud': '-5.962371106824864'}
# {'nombre': '153_AVENIDA REINA MERCEDES', 'slots': '27', 'vacios': '2', 'libres': '25', 'latitud': '37.36297137649665', 'longitud': '-5.986262173333679'}
# {'nombre': '140 NUESTRA SEÑORA DE LAS MERCEDES', 'slots': '16', 'vacios': '12', 'libres': '3', 'latitud': '37.3723704173039', 'longitud': '-5.97736214754443'}
# {'nombre': '017_CALLE DE MADRESELVA', 'slots': '20', 'vacios': '15', 'libres': '4', 'latitud': '37.40715155556869', 'longitud': '-5.978840172776446'}
# {'nombre': '049_ALAMEDA DE HERCULES', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.39686550900737', 'longitud': '-5.99392721978722'}
# {'nombre': '091_CALLE PROCURADOR', 'slots': '20', 'vacios': '18', 'libres': '1', 'latitud': '37.38690746421921', 'longitud': '-6.007674262301094'}
# {'nombre': '110_CIUDAD DE RONDA', 'slots': '20', 'vacios': '0', 'libres': '19', 'latitud': '37.37972144428237', 'longitud': '-5.983801174387398'}
# {'nombre': '115_CALLE LOPEZ DE GOMARA', 'slots': '20', 'vacios': '10', 'libres': '10', 'latitud': '37.377892428375446', 'longitud': '-6.007237255573729'}
# {'nombre': '191_GLORIETA CARLOS CANO', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.37411641267212', 'longitud': '-6.008853259077473'}
# {'nombre': '205_AVENIDA KANSAS CITY', 'slots': '20', 'vacios': '10', 'libres': '8', 'latitud': '37.39981714629299', 'longitud': '-5.961922341869038'}
# {'nombre': '222_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '16', 'vacios': '7', 'libres': '9', 'latitud': '37.40508356497133', 'longitud': '-5.933616012901859'}
# {'nombre': '177_AVENIDA ALCALDE JUAN FERNÁNDEZ', 'slots': '17', 'vacios': '12', 'libres': '5', 'latitud': '37.373068423133994', 'longitud': '-5.9690941189446'}
# {'nombre': '088_CALLE AMERICO VESPUCIO', 'slots': '20', 'vacios': '11', 'libres': '9', 'latitud': '37.40934127713802', 'longitud': '-6.006338859390215'}
# {'nombre': '007_CALLE AMÉRICO VESPUCIO', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.4074694906696', 'longitud': '-6.007603350403363'}
# {'nombre': '045_CARRETERA DE CARMONA', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.39992052707672', 'longitud': '-5.97781616502751'}
# {'nombre': '086_CAMINO DE LOS DESCUBRIMIENTOS', 'slots': '40', 'vacios': '34', 'libres': '5', 'latitud': '37.39707250530929', 'longitud': '-6.006304263337968'}
# {'nombre': '005_CAMINO DE LOS DESCUBRIMIENTOS', 'slots': '40', 'vacios': '0', 'libres': '39', 'latitud': '37.41104356266495', 'longitud': '-6.001959256107801'}
# {'nombre': '176_AVENIDA DE LA CIUDAD JARDÍN', 'slots': '20', 'vacios': '10', 'libres': '9', 'latitud': '37.3775594419921', 'longitud': '-5.966557112643772'}
# {'nombre': '083_AVENIDA LA BUHAIRA', 'slots': '20', 'vacios': '11', 'libres': '9', 'latitud': '37.386955475268515', 'longitud': '-5.978051158384551'}
# {'nombre': '193_AVENIDA DE CORIA', 'slots': '20', 'vacios': '8', 'libres': '11', 'latitud': '37.38111143948424', 'longitud': '-6.012005274166835'}
# {'nombre': '212_AVENIDA REINIDO UNIDO', 'slots': '15', 'vacios': '1', 'libres': '14', 'latitud': '37.351582337691354', 'longitud': '-5.977784137525409'}
# {'nombre': '018_AVENIDA EDUARDO DATO', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.38207545943934', 'longitud': '-5.968121120738779'}
# {'nombre': '099_CALLE AMÉRICO VESPUCIO', 'slots': '40', 'vacios': '35', 'libres': '5', 'latitud': '37.397394505010546', 'longitud': '-6.010641278744458'}
# {'nombre': '069_CALLE JOSE LAGUILLO', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.39201049535389', 'longitud': '-5.978293162147303'}
# {'nombre': '198_CALLE MAR DE ALBORÁN', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.42044661256891', 'longitud': '-5.967956142243533'}
# {'nombre': '219_CALLE DE LA A.D.A.', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.3905365010144', 'longitud': '-5.959072093702479'}
# {'nombre': '137_AVENIDA DE LA BORBOLLA', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.37375841984501', 'longitud': '-5.985517176959137'}
# {'nombre': '068_CALLE JUAN ANTONIO CABESTANY', 'slots': '15', 'vacios': '14', 'libres': '0', 'latitud': '37.39029248788509', 'longitud': '-5.979964167018684'}
# {'nombre': '254_ALHAMBRA', 'slots': '30', 'vacios': '18', 'libres': '12', 'latitud': '37.32942977136568', 'longitud': '-5.968971229675001'}
# {'nombre': '138_CALLE RAMÓN CARANDE', 'slots': '20', 'vacios': '1', 'libres': '18', 'latitud': '37.374370424709774', 'longitud': '-5.978934154215835'}
# {'nombre': '260_REVOLTOSA', 'slots': '20', 'vacios': '9', 'libres': '11', 'latitud': '37.377023215492045', 'longitud': '-5.947035486155897'}
# {'nombre': '042_PLAZA CRONISTA', 'slots': '15', 'vacios': '12', 'libres': '2', 'latitud': '37.3987059174522', 'longitud': '-5.989460016816095'}
# {'nombre': '199_MAR DE ALBORÁN', 'slots': '20', 'vacios': '4', 'libres': '16', 'latitud': '37.417855601747895', 'longitud': '-5.969296145455354'}
# {'nombre': '113_PLAZA SAN MARTÍN DE PORRES', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.380778439190046', 'longitud': '-6.009179264054355'}
# {'nombre': '094_PLAZA DEL ZURRAQUE', 'slots': '18', 'vacios': '18', 'libres': '0', 'latitud': '37.383369449862734', 'longitud': '-6.008294262440252'}
# {'nombre': '152_CALLE SAMANIEGO', 'slots': '20', 'vacios': '11', 'libres': '7', 'latitud': '37.3957905118738', 'longitud': '-5.97437315057576'}
# {'nombre': '098_AVENIDA DE ROMA', 'slots': '30', 'vacios': '0', 'libres': '30', 'latitud': '37.382043350305', 'longitud': '-5.993030169261488'}
# {'nombre': '003_PUERTA DE LA BARQUETA', 'slots': '40', 'vacios': '30', 'libres': '9', 'latitud': '37.40564154237001', 'longitud': '-5.998488240831263'}
# {'nombre': '019_PARLAMENTO', 'slots': '20', 'vacios': '16', 'libres': '1', 'latitud': '37.403327536585486', 'longitud': '-5.989037206345736'}
# {'nombre': '147_CARRETERA DE CARMONA', 'slots': '15', 'vacios': '13', 'libres': '2', 'latitud': '37.40079553153059', 'longitud': '-5.975228156455095'}
# {'nombre': '185_AVENIDA ALCALDE MANUEL DEL VALLE', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.40509431569403', 'longitud': '-5.968862135165761'}
# {'nombre': '239_CALLE CIUDAD DE LIRIA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.408691582745696', 'longitud': '-5.927718994548674'}
# {'nombre': '029_CARRETERA DE CARMONA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.402463540044714', 'longitud': '-5.970145139589757'}
# {'nombre': '182_CALLE VICTORIA KENT', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.41459658707776', 'longitud': '-5.973881159661203'}
# {'nombre': '172_RONDA TAMARGUILLO', 'slots': '20', 'vacios': '10', 'libres': '7', 'latitud': '37.367172398818624', 'longitud': '-5.971211122957581'}
# {'nombre': '156_AVENIDA KANSAS CITY', 'slots': '20', 'vacios': '15', 'libres': '3', 'latitud': '37.391453411096606', 'longitud': '-5.972761755091493'}
# {'nombre': '161_AVENIDA ALCALDE MANUEL DEL VALLE', 'slots': '20', 'vacios': '18', 'libres': '1', 'latitud': '37.40000053060032', 'longitud': '-5.969103134518509'}
# {'nombre': '023_PARLAMENTO', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.403337536978945', 'longitud': '-5.98787920228648'}
# {'nombre': '008_CALLE AMERICO VESPUCIO', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.4009693828541', 'longitud': '-6.00938173537619'}
# {'nombre': '164_CALLE LUIS MONTOTO', 'slots': '19', 'vacios': '17', 'libres': '2', 'latitud': '37.387649350924015', 'longitud': '-5.965655252045698'}
# {'nombre': '004_CALLE LEONARDO DA VINCI', 'slots': '40', 'vacios': '11', 'libres': '29', 'latitud': '37.41011155757378', 'longitud': '-6.005722268777397'}
# {'nombre': '136_CALLE ASUNCIÓN', 'slots': '20', 'vacios': '18', 'libres': '1', 'latitud': '37.37311941284756', 'longitud': '-5.997610219028108'}
# {'nombre': '015_CALLE DR MARAÑON', 'slots': '15', 'vacios': '14', 'libres': '1', 'latitud': '37.40604157176221', 'longitud': '-5.985733700014785'}
# {'nombre': '104_AVENIDA EDUARDO DATO', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.38413592692444', 'longitud': '-5.979676676296534'}
# {'nombre': '179_RONDA URBANA NORTE', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.413163177395056', 'longitud': '-5.985131221637643'}
# {'nombre': '166_RONDA DEL TAMARGUILLO', 'slots': '13', 'vacios': '13', 'libres': '0', 'latitud': '37.38859048869724', 'longitud': '-5.959240093357595'}
# {'nombre': '006_CAMINO DE LOS DESCUBRIMIENTOS', 'slots': '20', 'vacios': '0', 'libres': '20', 'latitud': '37.40661378981103', 'longitud': '-6.002977947581603'}
# {'nombre': '013_CALLE FERIA', 'slots': '15', 'vacios': '14', 'libres': '1', 'latitud': '37.40313353475898', 'longitud': '-5.991918216341031'}
# {'nombre': '170_PLAZA ANTONIO APARICIO HERRERO', 'slots': '18', 'vacios': '16', 'libres': '2', 'latitud': '37.37896644673701', 'longitud': '-5.968923121755333'}
# {'nombre': '240_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.402579544488994', 'longitud': '-5.940435585086025'}
# {'nombre': '044_RONDA CAPUCHINOS', 'slots': '15', 'vacios': '11', 'libres': '4', 'latitud': '37.39833897229492', 'longitud': '-5.981640026763738'}
# {'nombre': '084_CALLE JOSÉ MARÍA MORENO GALVÁN', 'slots': '20', 'vacios': '12', 'libres': '6', 'latitud': '37.387350475004816', 'longitud': '-5.983068176211725'}
# {'nombre': '245_CALLE LAS LEANDRAS', 'slots': '15', 'vacios': '8', 'libres': '7', 'latitud': '37.37539881124939', 'longitud': '-5.952549466245021'}
# {'nombre': '150_CALLE SAN JUAN BOSCO', 'slots': '20', 'vacios': '7', 'libres': '13', 'latitud': '37.39674851413617', 'longitud': '-5.978634166071806'}
# {'nombre': '093_RONDA DE TRIANA', 'slots': '15', 'vacios': '13', 'libres': '2', 'latitud': '37.38312344793415', 'longitud': '-6.010876271362328'}
# {'nombre': '204_CALLE DOCTOR LAFFON', 'slots': '15', 'vacios': '10', 'libres': '4', 'latitud': '37.39768969188425', 'longitud': '-5.96160136486722'}
# {'nombre': '078_CALLE ALFARERIA', 'slots': '20', 'vacios': '19', 'libres': '1', 'latitud': '37.38857113316299', 'longitud': '-6.010282378350756'}
# {'nombre': '130_GLORIETA REPUBLICA DOMINICANA', 'slots': '20', 'vacios': '6', 'libres': '14', 'latitud': '37.37574541795484', 'longitud': '-6.005247727302032'}
# {'nombre': '031_AVENIDA DE MIRAFLORES', 'slots': '13', 'vacios': '13', 'libres': '0', 'latitud': '37.40054152885159', 'longitud': '-5.979781172277264'}
# {'nombre': '163_CALLE SINAÍ', 'slots': '14', 'vacios': '11', 'libres': '3', 'latitud': '37.38995448989595', 'longitud': '-5.970802134688754'}
# {'nombre': '120_GLORIETA SAN DIEGO', 'slots': '15', 'vacios': '2', 'libres': '13', 'latitud': '37.37896144135567', 'longitud': '-5.989966195594725'}
# {'nombre': '210_PASEO DE EUROPA', 'slots': '15', 'vacios': '9', 'libres': '4', 'latitud': '37.348061320332235', 'longitud': '-5.980058142587488'}
# {'nombre': '030_AVENIDA EDUARDO DATO', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.382628460642394', 'longitud': '-5.970853130640082'}
# {'nombre': '002_GRAN PLAZA', 'slots': '18', 'vacios': '16', 'libres': '2', 'latitud': '37.381578045327934', 'longitud': '-5.96522396639778'}
# {'nombre': '037_ALAMEDA DE HÉRCULES', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.398785772824745', 'longitud': '-5.99318901314001'}
# {'nombre': '233_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '15', 'vacios': '1', 'libres': '13', 'latitud': '37.404112556103925', 'longitud': '-5.937092024971125'}
# {'nombre': '236_CIUDAD DE CHIVA', 'slots': '15', 'vacios': '13', 'libres': '2', 'latitud': '37.4102171143178', 'longitud': '-5.926422374057527'}
# {'nombre': '175_RONDA TAMARGUILLO', 'slots': '20', 'vacios': '11', 'libres': '8', 'latitud': '37.37775744487495', 'longitud': '-5.960870092813821'}
# {'nombre': '201_CALLE PINO MONTANO', 'slots': '20', 'vacios': '13', 'libres': '7', 'latitud': '37.41568359361039', 'longitud': '-5.967858139167567'}
# {'nombre': '107_CALLE LUIS MORALES', 'slots': '30', 'vacios': '25', 'libres': '5', 'latitud': '37.38425946651307', 'longitud': '-5.972591137677613'}
# {'nombre': '139_AVENIDA DIEGO MARTINEZ BARRIO', 'slots': '15', 'vacios': '7', 'libres': '8', 'latitud': '37.375075258863696', 'longitud': '-5.975863125578401'}
# {'nombre': '197_CALLE AGRICULTORES', 'slots': '20', 'vacios': '2', 'libres': '7', 'latitud': '37.423438625065074', 'longitud': '-5.96640413851815'}
# {'nombre': '181_RONDA URBANA NORTE', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.41335157894307', 'longitud': '-5.982568189409848'}
# {'nombre': '034_PLAZA PUMAREJO', 'slots': '15', 'vacios': '9', 'libres': '6', 'latitud': '37.40102752757453', 'longitud': '-5.988578203413862'}
# {'nombre': '252_GASPAR CALDERAS', 'slots': '25', 'vacios': '17', 'libres': '8', 'latitud': '37.32458203503861', 'longitud': '-5.968972128124462'}
# {'nombre': '040_AVENIDA REINA MERCEDES', 'slots': '30', 'vacios': '22', 'libres': '7', 'latitud': '37.35635082669173', 'longitud': '-5.986459877403918'}
# {'nombre': '050_CALLE DE HERNÁN CORTÉS', 'slots': '17', 'vacios': '15', 'libres': '2', 'latitud': '37.397554510745486', 'longitud': '-5.996695229895344'}
# {'nombre': '229_AVENIDA AERONAUTICA', 'slots': '15', 'vacios': '9', 'libres': '6', 'latitud': '37.38735449491008', 'longitud': '-5.919918954593122'}
# {'nombre': '151_CALLE URQUIZA', 'slots': '20', 'vacios': '12', 'libres': '8', 'latitud': '37.394544466945845', 'longitud': '-5.979897194354694'}
# {'nombre': '116_CALLE MANUEL SIUROT', 'slots': '20', 'vacios': '2', 'libres': '18', 'latitud': '37.36143037206055', 'longitud': '-5.981603156091943'}
# {'nombre': '155_AVENIDA KANSAS CITY', 'slots': '20', 'vacios': '14', 'libres': '6', 'latitud': '37.392910501713985', 'longitud': '-5.970739136171973'}
# {'nombre': '124_CALLE ENRAMADILLA', 'slots': '20', 'vacios': '1', 'libres': '19', 'latitud': '37.37773043874411', 'longitud': '-5.977244150228713'}
# {'nombre': '092_RONDA DE TRIANA', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.385838469752265', 'longitud': '-6.011220377621846'}
# {'nombre': '111_PZA FARMACÉUTICO MURILLO HERRERA', 'slots': '20', 'vacios': '15', 'libres': '4', 'latitud': '37.3813174443225', 'longitud': '-6.001053235842167'}
# {'nombre': '189_AVENIDA HYTASA', 'slots': '20', 'vacios': '17', 'libres': '3', 'latitud': '37.37005341642907', 'longitud': '-5.959496083704879'}
# {'nombre': '223_CALLE GEMA', 'slots': '15', 'vacios': '8', 'libres': '7', 'latitud': '37.40073135956411', 'longitud': '-5.92632420198497'}
# {'nombre': '121_CALLE DOCTOR PEDRO DE CASTRO', 'slots': '15', 'vacios': '2', 'libres': '12', 'latitud': '37.377158434736266', 'longitud': '-5.981935166355452'}
# {'nombre': '025_AVENIDA DE LA CRUZ ROJA', 'slots': '20', 'vacios': '10', 'libres': '10', 'latitud': '37.40313253870445', 'longitud': '-5.981109178424791'}
# {'nombre': '085_PASEO CATALINA RIBERA', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.38535146566221', 'longitud': '-5.986785188099708'}
# {'nombre': '076_PLAZA NUEVA', 'slots': '30', 'vacios': '12', 'libres': '18', 'latitud': '37.38893947673792', 'longitud': '-5.995646221258141'}
# {'nombre': '105_CALLE FRANCISCO MURILLO', 'slots': '19', 'vacios': '9', 'libres': '10', 'latitud': '37.358910362359936', 'longitud': '-5.980620151182153'}
# {'nombre': '114_GLORIETA PLUS ULTRA', 'slots': '30', 'vacios': '16', 'libres': '14', 'latitud': '37.356372352725714', 'longitud': '-5.979262144945245'}
# {'nombre': '144_AVENIDA DE LA PALMERA', 'slots': '20', 'vacios': '12', 'libres': '8', 'latitud': '37.36912633937041', 'longitud': '-5.988080397280193'}
# {'nombre': '215_CALLE ZORZAL', 'slots': '15', 'vacios': '9', 'libres': '6', 'latitud': '37.38664148025849', 'longitud': '-5.953981074150936'}
# {'nombre': '071_AVENIDA KANSAS CITY', 'slots': '18', 'vacios': '14', 'libres': '3', 'latitud': '37.39003048884624', 'longitud': '-5.974491147670695'}
# {'nombre': '108_AVENIDA EDUARDO DATO', 'slots': '15', 'vacios': '1', 'libres': '14', 'latitud': '37.382852503457265', 'longitud': '-5.973249491935667'}
# {'nombre': '230_AVENIDA DE LAS CIENCIAS', 'slots': '14', 'vacios': '14', 'libres': '0', 'latitud': '37.403927559446025', 'longitud': '-5.928139993197263'}
# {'nombre': '178_CALLE JOSÉ SARAMAGO', 'slots': '20', 'vacios': '18', 'libres': '2', 'latitud': '37.373304076262805', 'longitud': '-5.97391890132113'}
# {'nombre': '028_CALLE RAFAEL SALGADO', 'slots': '18', 'vacios': '4', 'libres': '13', 'latitud': '37.360261369216595', 'longitud': '-5.976659138066708'}
# {'nombre': '095_CALLE AMÉRICO VESPUCIO', 'slots': '20', 'vacios': '15', 'libres': '5', 'latitud': '37.41217356557977', 'longitud': '-6.006338272120392'}
# {'nombre': '057_PLAZA CRISTO DE BURGOS', 'slots': '15', 'vacios': '5', 'libres': '10', 'latitud': '37.39231861674279', 'longitud': '-5.989705187094715'}
# {'nombre': '225_CALLE FLOR DE RETAMA', 'slots': '15', 'vacios': '12', 'libres': '3', 'latitud': '37.397390540237105', 'longitud': '-5.918776956284244'}
# {'nombre': '231_AVENIDA ALCALDE LUIS URUÑUELA', 'slots': '15', 'vacios': '6', 'libres': '8', 'latitud': '37.401673546456635', 'longitud': '-5.942139041014662'}
# {'nombre': '127_CALLE VIRGEN DE LA VICTORIA', 'slots': '15', 'vacios': '13', 'libres': '1', 'latitud': '37.37764043077863', 'longitud': '-5.997947222820481'}
# {'nombre': '183_ALCALDE MANUEL DEL VALLE', 'slots': '15', 'vacios': '11', 'libres': '4', 'latitud': '37.41101757377389', 'longitud': '-5.97121914827267'}
# {'nombre': '238_CIUDAD DE CHIVA', 'slots': '15', 'vacios': '9', 'libres': '6', 'latitud': '37.408132573830756', 'longitud': '-5.919993048486191'}
# {'nombre': '039_PLAZA SAN ANTONIO DE PADUA', 'slots': '20', 'vacios': '15', 'libres': '4', 'latitud': '37.397840022304365', 'longitud': '-5.998504686877961'}
# {'nombre': '131_CALLE TABLADILLA', 'slots': '20', 'vacios': '2', 'libres': '18', 'latitud': '37.364750385373725', 'longitud': '-5.981452157485012'}
# {'nombre': '035_ALAMEDA DE HERCULES', 'slots': '20', 'vacios': '20', 'libres': '0', 'latitud': '37.400682524351275', 'longitud': '-5.993630220939186'}
# {'nombre': '129_CALLE VIRGEN DE LUJAN', 'slots': '20', 'vacios': '16', 'libres': '4', 'latitud': '37.374668417254036', 'longitud': '-6.002455236928109'}
# {'nombre': '174_RONDA TAMARGUILLO', 'slots': '20', 'vacios': '16', 'libres': '4', 'latitud': '37.38061245637617', 'longitud': '-5.960574093426685'}
# {'nombre': '072_CALLE AMADOR DE LOS RIOS', 'slots': '20', 'vacios': '12', 'libres': '6', 'latitud': '37.39071248853365', 'longitud': '-5.982768177096753'}
# {'nombre': '180_CALLE DOCTOR JAIME MARCOS', 'slots': '20', 'vacios': '18', 'libres': '1', 'latitud': '37.40964956350476', 'longitud': '-5.98440119371439'}
# {'nombre': '020_CALLE SAN JUAN DE RIBERA', 'slots': '15', 'vacios': '3', 'libres': '12', 'latitud': '37.404869543652175', 'longitud': '-5.986537198461927'}
# {'nombre': '052_CALLE DEL INCA GARCILASO', 'slots': '40', 'vacios': '8', 'libres': '16', 'latitud': '37.39422649248208', 'longitud': '-6.010309275759171'}
# {'nombre': '032_CALLE MUÑOZ LEÓN', 'slots': '15', 'vacios': '13', 'libres': '2', 'latitud': '37.402019532357485', 'longitud': '-5.986323196073661'}
# {'nombre': '157_AVENIDA CARDENAL BUENO MONREAL', 'slots': '20', 'vacios': '14', 'libres': '5', 'latitud': '37.369799405424466', 'longitud': '-5.978194722821982'}
# {'nombre': '112_AVDA ESPERANZA DE TRIANA', 'slots': '20', 'vacios': '14', 'libres': '6', 'latitud': '37.380153438452595', 'longitud': '-6.004383246859136'}
# {'nombre': '134_CALLE VIRGEN DE LUJÁN', 'slots': '24', 'vacios': '22', 'libres': '1', 'latitud': '37.374770419100905', 'longitud': '-5.998536223231469'}
# {'nombre': '070_ESTACIÓN RENFE SANTA JUSTA', 'slots': '40', 'vacios': '40', 'libres': '0', 'latitud': '37.39115849280489', 'longitud': '-5.975971153511849'}
# {'nombre': '159_AVENIDA CARDENAL BUENO MONREAL', 'slots': '20', 'vacios': '0', 'libres': '18', 'latitud': '37.36804539727759', 'longitud': '-5.984854171329494'}
# {'nombre': '135_CALLE VIRGEN DE LUJÁN', 'slots': '17', 'vacios': '4', 'libres': '12', 'latitud': '37.37465142036539', 'longitud': '-5.993801206544696'}
# {'nombre': '162_AVENIDA SOLEA', 'slots': '18', 'vacios': '15', 'libres': '3', 'latitud': '37.39154049708111', 'longitud': '-5.96846612741093'}
# {'nombre': '010_CALLE JOSE DIAZ', 'slots': '20', 'vacios': '19', 'libres': '0', 'latitud': '37.40938502560925', 'longitud': '-5.990766008714238'}
# {'nombre': '075_PLAZA SAN FRANCISCO', 'slots': '20', 'vacios': '5', 'libres': '15', 'latitud': '37.387997377700096', 'longitud': '-5.993587446638155'}
# {'nombre': '146_AVENIDA REINA MERCEDES', 'slots': '20', 'vacios': '10', 'libres': '10', 'latitud': '37.360100626411395', 'longitud': '-5.986312974875395'}
# {'nombre': '126_AVENIDA REINA MERCEDES', 'slots': '25', 'vacios': '12', 'libres': '13', 'latitud': '37.358164858839395', 'longitud': '-5.986482708713183'}
# {'nombre': '158_AVENIDA CARDENAL BUENO MONREAL', 'slots': '20', 'vacios': '19', 'libres': '0', 'latitud': '37.3688534016955', 'longitud': '-5.981618160442233'}
# {'nombre': '009_CAMINO DE LOS DESCUBRIMIENTOS', 'slots': '20', 'vacios': '3', 'libres': '17', 'latitud': '37.40332453110276', 'longitud': '-6.004020258912579'}
# {'nombre': '060_PLAZA DE LA CONCORDIA', 'slots': '19', 'vacios': '6', 'libres': '13', 'latitud': '37.39395749631202', 'longitud': '-5.996899228542791'}
# {'nombre': '064_CALLE CUESTA DE ROSARIO', 'slots': '15', 'vacios': '10', 'libres': '5', 'latitud': '37.38985648205481', 'longitud': '-5.991125205922743'}
# {'nombre': '218_PLAZA DEL ALTOZANO', 'slots': '14', 'vacios': '14', 'libres': '0', 'latitud': '37.38512441847878', 'longitud': '-6.003542147441712'}
# {'nombre': '063_CALLE SAN PABLO', 'slots': '20', 'vacios': '0', 'libres': '0', 'latitud': '37.390456481894525', 'longitud': '-5.998103230753266'}
# {'nombre': '074_PLAZA PILATOS', 'slots': '15', 'vacios': '5', 'libres': '10', 'latitud': '37.38977148326459', 'longitud': '-5.986897191039803'}
# {'nombre': '054_PLAZA SAN JUAN DE LA PALMA', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.39523950356959', 'longitud': '-5.991050208758028'}
# {'nombre': '089_CALLE ADRIANO', 'slots': '18', 'vacios': '9', 'libres': '9', 'latitud': '37.38648146613877', 'longitud': '-5.997790227366178'}
# {'nombre': '053_CALLE REYES CATÓLICOS', 'slots': '17', 'vacios': '2', 'libres': '15', 'latitud': '37.38934147689296', 'longitud': '-5.999605235382445'}
# {'nombre': '047_CALLE HINIESTA', 'slots': '15', 'vacios': '15', 'libres': '0', 'latitud': '37.39713251259333', 'longitud': '-5.987037195768433'}
# {'nombre': '065_CALLE ALHÓNDIGA', 'slots': '14', 'vacios': '12', 'libres': '2', 'latitud': '37.391299488908295', 'longitud': '-5.988140196280803'}
# {'nombre': '228_AVENIDA DE LAS CIENCIAS', 'slots': '15', 'vacios': '11', 'libres': '4', 'latitud': '37.394449523785354', 'longitud': '-5.921230963560515'}
# {'nombre': '250_CALLE DE SALVADOR ALLENDE', 'slots': '15', 'vacios': '4', 'libres': '10', 'latitud': '37.421879', 'longitud': '-5.985663'}
# {'nombre': '203_CALLE TESALÓNICA', 'slots': '20', 'vacios': '7', 'libres': '13', 'latitud': '37.396093518802566', 'longitud': '-5.958764096016824'}
# {'nombre': '145_AVENIDA REINA MERCEDES', 'slots': '20', 'vacios': '4', 'libres': '16', 'latitud': '37.360233228861155', 'longitud': '-5.986318234050904'}
# {'nombre': '048_CALLE CHURRUCA', 'slots': '15', 'vacios': '11', 'libres': '3', 'latitud': '37.39715651121527', 'longitud': '-5.991066209916829'}
# [{'nombre': 'name', 'slots': 'slots', 'vacios': 'empty_slots', 'libres': 'free_bikes', 'latitud': 'latitude', 'longitud': 'longitude'}, {'nombre': '149_CALLE ARROYO', 'slots': '20', 'vacios': '11', 'libres': '9', 'latitud': '37.397829929383', 'longitud': '-5.97567172039552'}, {'nombre': '257_TORRES ALBARRACIN', 'slots': '20', 'vacios': '16', 'libres': '4', 'latitud': '37.38376948792722', 'longitud': '-5.908921914235877'}, {'nombre': '243_GLORIETA DEL PRIMERO DE MAYO', 'slots': '15', 'vacios': '6', 'libres': '9', 'latitud': '37.380439481169994', 'longitud': '-5.953481197462845'}, {'nombre': '109_AVENIDA SAN FRANCISCO JAVIER', 'slots': '15', 'vacios': '1', 'libres': '14', 'latitud': '37.37988413609134', 'longitud': '-5.974382770011586'}, {'nombre': '073_PLAZA SAN AGUSTIN', 'slots': '15', 'vacios': '10', 'libres': '4', 'latitud': '37.38951386231434', 'longitud': '-5.984362789545622'}, {'nombre': '096_CALLE BETIS', 'slots': '19', 'vacios': '17', 'libres': '2', 'latitud': '37.3835407311529', 'longitud': '-5.999910722822249'}, {'nombre': '256_MIGUEL MONTORO', 'slots': '29', 'vacios': '27', 'libres': '1', 'latitud': '37.386100496778624', 'longitud': '-5.910090919676698'}, {'nombre': '082_CALLE LUIS MONTOTO', 'slots': '17', 'vacios': '12', 'libres': '5', 'latitud': '37.387098477016366', 'longitud': '-5.974843147214583'}, {'nombre': '226_AVENIDA DOCTOR EMILIO LEMOS', 'slots': '15', 'vacios': '10', 'libres': '5', 'latitud': '37.402862871745285', 'longitud': '-5.921753676327738'}]

# %% [markdown]
# ## 2.4. Serialización y deserialización mediante JSON <a name="sec_2_4"/>

# %% [markdown]
# Llamamos **serialización** al proceso de convertir los datos almacenados en una o varias variables de nuestro programa a una representación en formato textual o binario, de manera que posteriormente esta representación pueda ser utilizada para volver a cargar dichos datos en nuestro programa, proceso que se conoce como **deserialización**.
#
# La serialización/deserialización nos permite guardar el contenido de una variable tal cual en un fichero, de manera que en una ejecución posterior de nuestro programa (o de otro programa) esos datos puedan ser cargados fácilmente en otra variable, y se pueda seguir trabajando con ellos. Otra posibilidad es utilizar la representación obtenida para enviarla a través de Internet, de manera que permitamos que dos programas situados en máquinas distintas se envíen estos datos uno al otro; conseguimos así que ambos programas puedan colaborar como si se ejecutaran en una misma máquina y compartieran dicha variable. Esta es la base de los **servicios web**, aplicaciones que ofrecen funcionalidades que pueden ser utilizadas por programas a través del protocolo **http**. Por poner algunos ejemplos, es posible consultar información sobre artistas o canciones haciendo consultas a los servicios web ofrecidos por *Spotify*. La información requerida es serializada por los servidores de *Spotify*, y enviada por Internet como respuesta a la petición de un cliente. El programa del cliente deserializará dicha información y podrá utilizarla para llevar a cabo la funcionalidad que se desee.
#
# Un formato estándar de intercambio de datos ampliamente utilizado y muy bien integrado en Python es **json**. De hecho, la representación de los datos en *json* es muy parecida a la propia sintaxis de Python. Puedes comprobarlo en el siguiente ejemplo, en el que serializamos la variable glosario:

# %%
import json

glosario = {'programación estructurada': [14,15,18,24,85,86], 'funciones': [2,3,4,8,9,10,11,14,15,18]}
glosario_json = json.dumps(glosario)
print(glosario_json)
# Out:
# {"programaci\u00f3n estructurada": [14, 15, 18, 24, 85, 86], "funciones": [2, 3, 4, 8, 9, 10, 11, 14, 15, 18]}

# %% [markdown]
# Aunque la variable que se está serializando en este ejemplo es simple, con el mismo código podemos serializar cualquier variable, sea cual sea la complejidad de los datos que almacena.
#
# Para deserializar la representación *json* obtenida, lo haremos así:

# %%
glosario = json.loads(glosario_json)
print(glosario)
# Out:
# {'programación estructurada': [14, 15, 18, 24, 85, 86], 'funciones': [2, 3, 4, 8, 9, 10, 11, 14, 15, 18]}

# %% [markdown]
# Si combinamos los ejemplos anteriores con la escritura y lectura de ficheros de texto, podemos guardar en un fichero el contenido de la variable, y en una ejecución posterior leer el fichero y cargar dichos datos de nuevo en una variable:

# %%
glosario = {'programación estructurada': [14,15,18,24,85,86], 'funciones': [2,3,4,8,9,10,11,14,15,18]}
glosario_json = json.dumps(glosario)
print('Almacenando la variable glosario en el fichero glosario.txt')
with open('glosario.txt','w') as f:
    f.write(glosario_json)
# Out:
# Almacenando la variable glosario en el fichero glosario.txt

# %%
print('Cargando los datos del fichero glosario.txt en la variable glosario')
with open('glosario.txt') as f:
    glosario_json = f.read()
    glosario = json.loads(glosario_json)
    print('Datos cargados:', glosario)
# Out:
# Cargando los datos del fichero glosario.txt en la variable glosario
# Datos cargados: {'programación estructurada': [14, 15, 18, 24, 85, 86], 'funciones': [2, 3, 4, 8, 9, 10, 11, 14, 15, 18]}

# %% [markdown]
# La deserialización de *json* nos permite hacer multitud de consultas a diversos servicios web, y trabajar con los datos obtenidos directamente en nuestro programa Python. Por ejemplo, el siguiente ejemplo muestra cómo obtener la información sobre las estaciones de bicicletas de alquiler de Sevici (servicio público de alquiler de bicicletas de Sevilla), a través del servicio web ofrecido por https://citybik.es/:

# %%
import urllib.request

# urllib.request.urlopen es parecido a la función open, pero en lugar de leer
# desde un fichero estamos leyendo una dirección http
with urllib.request.urlopen("https://api.citybik.es/v2/networks/sevici") as f:
    sevici_json = f.read()
    estaciones = json.loads(sevici_json)
    print(estaciones)
# Out:
# {'network': {'company': ['JCDecaux'], 'href': '/v2/networks/sevici', 'id': 'sevici', 'license': {'name': 'Open Licence', 'url': 'https://developer.jcdecaux.com/#/opendata/licence'}, 'location': {'city': 'Sevilla', 'country': 'ES', 'latitude': 37.3880961, 'longitude': -5.9823299}, 'name': 'Sevici', 'source': 'https://developer.jcdecaux.com', 'stations': [{'empty_slots': 13, 'extra': {'address': 'PLAZA NUEVA - Aprox. C/ Mendez Núñez', 'banking': True, 'bonus': False, 'last_update': 1606292489000, 'slots': 20, 'status': 'OPEN', 'uid': 242}, 'free_bikes': 7, 'id': 'd5470c8bd4fcea96295747146833c850', 'latitude': 37.38881830392981, 'longitude': -5.995750976296489, 'name': '242_PLAZA NUEVA', 'timestamp': '2020-11-25T08:23:05.623000Z'}, {'empty_slots': 1, 'extra': {'address': 'PLAZA NUEVA - Aprox. C/ Jaen', 'banking': True, 'bonus': False, 'last_update': 1606292295000, 'slots': 30, 'status': 'OPEN', 'uid': 76}, 'free_bikes': 29, 'id': '631add9c5f015627addf1d9c2edee7dd', 'latitude': 37.3889394767379, 'longitude': -5.99564622125814, 'name': '076_PLAZA NUEVA', 'timestamp': '2020-11-25T08:23:05.808000Z'}, {'empty_slots': 19, 'extra': {'address': 'CALLE PARQUE DE DOÑANA - Aprox. Calle Corral de los Olmos', 'banking': True, 'bonus': False, 'last_update': 1606292541000, 'slots': 20, 'status': 'OPEN', 'uid': 194}, 'free_bikes': 0, 'id': '226239bb2cc5780404add299da3c4636', 'latitude': 37.418732603824466, 'longitude': -5.97319415962488, 'name': '194_CALLE PARQUE DE DOÑANA', 'timestamp': '2020-11-25T08:23:05.514000Z'}, {'empty_slots': 8, 'extra': {'address': 'AVENIDA REINA MERCEDES - Aprox. Facultad de Informática', 'banking': True, 'bonus': False, 'last_update': 1606292474000, 'slots': 25, 'status': 'OPEN', 'uid': 126}, 'free_bikes': 17, 'id': 'c82bd767011e78ecab4f630637a20300', 'latitude': 37.358164858839395, 'longitude': -5.986482708713183, 'name': '126_AVENIDA REINA MERCEDES', 'timestamp': '2020-11-25T08:23:05.517000Z'}, {'empty_slots': 8, 'extra': {'address': 'PLAZA SAN AGUSTIN - Aprox. C/ Concepción', 'banking': True, 'bonus': False, 'last_update': 1606282518000, 'slots': 15, 'status': 'OPEN', 'uid': 73}, 'free_bikes': 7, 'id': '951d9a15a4feba656b01b29923387821', 'latitude': 37.38951386231434, 'longitude': -5.984362789545622, 'name': '073_PLAZA SAN AGUSTIN', 'timestamp': '2020-11-25T08:23:05.518000Z'}, {'empty_slots': 18, 'extra': {'address': 'CALLE ORFEBRE DOMINGUEZ VÁZQUEZ - Aprox. C/ Pino Montano', 'banking': True, 'bonus': False, 'last_update': 1606292075000, 'slots': 20, 'status': 'OPEN', 'uid': 186}, 'free_bikes': 2, 'id': '3077f6e052b55a72fd0dd39e03cd3bb9', 'latitude': 37.40860456343952, 'longitude': -5.973161153696026, 'name': '186_CALLE ORFEBRE DOMINGUEZ VÁZQUEZ', 'timestamp': '2020-11-25T08:23:05.519000Z'}, {'empty_slots': 9, 'extra': {'address': 'PASEO CATALINA RIBERA - Aprox. C/ San Fernando', 'banking': True, 'bonus': False, 'last_update': 1606292239000, 'slots': 20, 'status': 'OPEN', 'uid': 100}, 'free_bikes': 11, 'id': '975f84a3b28ddb79ae65224738358442', 'latitude': 37.381516148333745, 'longitude': -5.98899864813969, 'name': '100_PASEO CATALINA RIBERA', 'timestamp': '2020-11-25T08:23:05.520000Z'}, {'empty_slots': 3, 'extra': {'address': 'CALLE BETIS - Aprox. C/ Juan de Lugo', 'banking': True, 'bonus': False, 'last_update': 1606292462000, 'slots': 19, 'status': 'OPEN', 'uid': 96}, 'free_bikes': 16, 'id': '86dcc1cad87d8c714d67f25f5b1c676b', 'latitude': 37.3835407311529, 'longitude': -5.999910722822249, 'name': '096_CALLE BETIS', 'timestamp': '2020-11-25T08:23:05.521000Z'}, {'empty_slots': 2, 'extra': {'address': 'CALLE PAEZ DE RIVERA - Aprox. Paseo de la Palmera', 'banking': True, 'bonus': False, 'last_update': 1606292023000, 'slots': 20, 'status': 'OPEN', 'uid': 132}, 'free_bikes': 18, 'id': '9422d2414a31f20c0216517069d21b97', 'latitude': 37.36361937962884, 'longitude': -5.984785168525709, 'name': '132_CALLE PAEZ DE RIVERA', 'timestamp': '2020-11-25T08:23:05.522000Z'}, {'empty_slots': 27, 'extra': {'address': 'Esquina Calle P ...

# %% [markdown]
# El objeto que hemos cargado en la variable estaciones tiene una estructura compleja, por lo que es conveniente consultar la [documentación del servicio](https://api.citybik.es/v2/) si queremos utilizar dichos datos en nuestro programa. Observe el abundante uso de diccionarios y listas. Por ejemplo, es posible acceder a las direcciones de todas las estaciones mediante este código:

# %%
with urllib.request.urlopen("https://api.citybik.es/v2/networks/sevici") as f:
    sevici_json = f.read()
    estaciones = json.loads(sevici_json)
    for estacion in estaciones['network']['stations']:
        print(estacion['extra']['address'])
# Out:
# PLAZA NUEVA - Aprox. C/ Mendez Núñez
# PLAZA NUEVA - Aprox. C/ Jaen
# CALLE PARQUE DE DOÑANA - Aprox. Calle Corral de los Olmos
# AVENIDA REINA MERCEDES - Aprox. Facultad de Informática
# PLAZA SAN AGUSTIN - Aprox. C/ Concepción
# CALLE ORFEBRE DOMINGUEZ VÁZQUEZ - Aprox. C/ Pino Montano
# PASEO CATALINA RIBERA - Aprox. C/ San Fernando
# CALLE BETIS - Aprox. C/ Juan de Lugo
# CALLE PAEZ DE RIVERA - Aprox. Paseo de la Palmera
# Esquina Calle Pero Mingo
# CALLE LUIS MONTOTO - Aprox. C/ Maese Farfán
# AVENIDA MUJER TRABAJADORA - Aprox. Avda Miraflores
# AVENIDA DOCTOR EMILIO LEMOS - Aprox. C/ de Birmania
# AVENIDA EDUARDO DATO - Aprox. C/ San Bernardo
# CALLE DE MANUEL VILLALOBOS - Aprox. C/ Sor Francisca Dorotea
# CALLE RAMON DE CARRANZA - Aprox. C/ Virgen de la Oliva
# PLAZA DEL PELICANO - Aprox. C/ Enladrilladas
# AVENIDA ALEMANIA - Aprox. Glorieta Chekia
# AVENIDA DE MIRAFLORES - Aprox. C/ Manuel Ródenas
# Esquina rotanda Torreblanca
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Hotel Sevilla Congresos
# Virgen de Loreto - Aprox. C/ Arcos
# CAMINO DE LOS DESCUBRIMIENTOS - Aprox. C/ Albert Einstein
# AVENIDA DE CHILE - Aprox. Costurero de la Reina
# CALLE LEÓN XIII - Aprox. C/ Antonio Pantión
# CAMINO DE LOS TOROS - Aprox. C/ Mediterráneo
# PLAZA CHAPINA - Aprox. Hotel Abba Triana
# CALLE NAVARRA - Aprox. C/ Cataluña
# PLAZA NUEVA - Aprox. C/ Tetuan
# AVENIDA HYTASA - Aprox. C/ Romeral
# CALLE SAN VICENTE - Aprox. C/ Guadalquivir
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Centro Comercial Zona Este
# CALLE MANUEL VILLALOBOS - Aprox. C/ Madre San Marcelo
# AVENIDA KANSAS CITY - Aprox. C/ Naranjito de Triana
# CALLE LEÓN XIII - Aprox. C/ Fray Isidoro de Sevilla
# CALLE DE INCA GARCILASO - Aprox. C/ Juan Antonio de Vizarrón
# CALLE TESALÓNICA - Calle Mazzantini
# CALLE CORRAL DEL AGUA - Aprox. Camino de los toros
# PLAZA DUQUESA DE ALBA - Puente de la Barqueta
# PLAZA NUEVA - Aprox. C/ Mendez Núñez
# PLAZA DE LA CONCORDIA - Aprox. C/ Teniente Borges
# AAVENIDA DE GRECIA - Aprox. Avda de Italia
# AVENIDA RAMÓN Y CAJAL - Aprox. Avda de la Ciudad Jardín
# AVENIDA RAMÓN Y CAJAL - Aprox. C/ Villegas Marmolejo
# AVENIDA KANSAS CITY - Aprox. C/ Macedonia
# CALLE ARROYO - Aprox. Avda. José Laguillo
# PLAZA DEL MUSEO - Aprox. C/ Alfonso XII
# AVENIDA DE ALEMANIA - Aprox. Glorieta de Letonia
# PLAZA CALDERÓN DE LA BARCA - Aprox. C/ Amargura
# AVENIDA SAN FRANCISCO JAVIER - Aprox. Avda De Ramón y Cajal
# CALLE REGINA - Aprox. Pza de la Encarnación
# CALLE THARSIS - Aprox. C/ Aorno
# PLAZA DE CUBA - Aprox. Puente de San Telmo
# CALLE ENRAMADILLA - Aprox. C/ Balbino Marrón
# AVENIDA DE ALVAR NUÑEZ - Aprox. C/ Collante
# PRADO DE SAN SEBASTIAN - Estación de autobuses
# CALLE LEONARDO DA VINCI - Aprox. C/ Albert Einstein
# PUERTO DE LOS AZORES - Aprox. C/ Paulo Orosio
# CALLE IFNI - Aprox. Avda de Holanda
# CALLE JUAN DE MATA CARRIAZO - Aprox. antigua estación San Bernardo
# RONDA TAMARGUILLO - Aprox. Avda de la Paz
# AVENIDA SANCHEZ PIZJUAN - Facultad de Medicina
# CALLE ALFONSO LASO DE LA VEGA - Aprox. Parroco Antonio González
# AVENIDA DE LA PALMERA - Aprox. Avenida del Líbano
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Pza de la Acogida
# GLORIETA BIZCO AMATE - Aprox. Avda Ramón y Cajal
# CALLE LUIS MONTOTO - Aprox. C/ Benitos Mas y Prat
# CALLE MÉDICOS SIN FRONTERA - Aprox. Avda de las Ciencias
# HOPITAL VALME.-Esquina Carretera Bellasvistas
# CALLE CUESTA DE ROSARIO - Pza de la Pescadería
# PLAZA DE LAS MERCEDARIAS - Aprox. C/ Ibarra
# CIUDAD DE CHIVA - Aprox. C/ ciudad de Alfajar
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. C/ Carlinga
# CALLE ROMA - Aprox. C/ Palos de la Frontera
# AVENIDA DE LAS CIENCIAS - Aprox. C/ de Ulises
# AVDA ESPERANZA DE TRIANA - Aprox. Avda Republica Argentina
# PASEO CRISTOBAL COLON - Aprox. Puente de Triana
# ESTADIO OLIMPICO
# Esquina Calle Creus
# CALLE RAMON DE CARRANZA - Aprox. C/ Asunción
# AVENIDA LOS GAVILANES - Aprox. Avda Juan XXIII
# AVENIDA HYTASA - Aprox. C/ Herramienta
# Esquina con C/Enramadilla
# AVENIDA TORNEO - Aprox. C/ Luis Rey Romero
# Esquina con Alejandro Collantes
# CALLE FELIPE II - Aprox. C/ Ramón Carande
# RONDA CAPUCHINOS - Aprox. C/ Maestro Quiroga
# CIUDAD DE CHIVA - Aprox. C/ Ildefonso Marañon
# Avda Alberto Jiménez Becerril - Antes Calle Maimonides
# PLAZA DEL ALTOZANO - Aprox. C/ San Jorge
# AVENIDA DE LLANES - Aprox C/ Escultor Francisco Buiza
# GLORIETA OLIMPICA - Aprox. Concejal Alberto Jiménez-Becerril
# CALLE ESTRELLA CANOPUS - Aprox. C/ estrella Betelgeuse
# CALLE DE LA A.D.A. - Aprox. C/ Jerusalén
# PLAZA DE ARMAS - Avda Torneo (estación de autobuses)
# AVENIDA REINA MERCEDES - Aprox. Escuela de arquitectura
# CALLE ANTIOQUIA - Aprox. Avda de Pedro Romero
# 140 NUESTRA SEÑORA DE LAS MERCEDES
# CALLE CHURRUCA - Aprox. C/ Gonzáles Cuadrado
# GLORIETA DE LOS FERROVIARIOS - Aprox. C/ Navarra
# CALLE LUIS MONTOTO - Aprox. C/ Alberto Duero
# 261: AVDA/ JUAN PABLO II - – ESQUINA C/ ALFONSO DE ORLEANS Y BORBÓN.
# CALLE DE MADRESELVA - Aprox. Ronda de Pio XII
# ALAMEDA DE HERCULES - Aprox. C/ Amor de Dios
# CALLE PROCURADOR - Clara de Jesús Monteto
# Ciudad de Ronda - Aprox. Avda Carlos V
# AVENIDA ALCALDE MANUEL DEL VALLE - Aprox. C/ San Juan de la Salle
# AVENIDA SANTA FE - Aprox. C/ Virgen de la Oliva
# CALLE LOPEZ DE GOMARA - En frente Instituto Adolfo Becker
# GLORIETA CARLOS CANO - Aprox. C/ Blas Infante
# CALLE DOCTOR LAFFON - Aprox. C/ Efeso
# AVENIDA DE ANDALUCIA - Aprox. Centro Comercial Los Arcos
# AVENIDA KANSAS CITY - Aprox. Pza el Tato
# CALLE ARROYO - Aprox. C/ Tena
# Esquina Calle Aguila Perdicera
# CALLE DE SALVADOR ALLENDE - Aprox. C/ de Marruecos
# AVENIDA EDUARDO DATO - Aprox. C/ Oscar Carvallo
# AVENIDA DE LLANES - Aprox. Avda de Miraflores
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Palacio de los Congresos
# AVENIDA ALCALDE JUAN FERNÁNDEZ - Aprox. C/ Profesor Buenaventura Pinillos
# CALLE AMERICO VESPUCIO - Aprox. C/ Hermanos d'Eluyar
# PASEO DE CRISTÓBAL COLÓN - Aprox. Torre del Oro
# CALLE AMÉRICO VESPUCIO - Aprox. Calle de Jacques Cousteau
# CARRETERA DE CARMONA - Aprox. C/ de Francisco de Ariño
# Esquina corazon de MAria
# CAMINO DE LOS DESCUBRIMIENTOS - Aprox. Pasarela de la Cartuja
# CAMINO DE LOS DESCUBRIMIENTOS - Aprox. C/ Thomás Alba Edison
# CALLE LUIS MONTOTO - Aprox. C/ El Greco
# CALLE LEONARDO DA VINCI - Aprox C/ Thomas Alba Edison
# CALLE ASUNCIÓN - Aprox. C/ Virgen de la Antigua
# AVENIDA DE LA CIUDAD JARDÍN - Aprox. C/ Profesor Braña
# AVENIDA LA BUHAIRA - Aprox. Avda Luis Montoto
# CALLE DR MARAÑON - Aprox. C/ San Juan de Ribera
# AVENIDA EDUARDO DATO - Aprox. C/ Fuenteovejuna
# AVENIDA DE CORIA - Aprox. C/ Coruña
# AVENIDA REINIDO UNIDO - Aprox. Avda de Italia
# RONDA DEL TAMARGUILLO - Aprox. Centro Comercial Los Arcos
# AVENIDA EDUARDO DATO - Aprox. C/ Marqués del Nervión
# CAMINO DE LOS DESCUBRIMIENTOS - Aprox. Calle Isaac Newton
# CALLE AMÉRICO VESPUCIO - Aprox. Gerencia de Urbanismo de Sevilla
# CALLE FERIA - Aprox. C/ Resolana
# CALLE JOSE LAGUILLO - Aprox. Pablo Iglesias
# PLAZA ANTONIO APARICIO HERRERO - Aprox. C/ San Juan de Dios
# CALLE MAR DE ALBORÁN - Aprox. C/ Camino de los Toros
# CALLE DE LA A.D.A. - Aprox. C/ de Tesalónica
# AVENIDA DE LA BORBOLLA - Aprox. C/ Porvenir
# CALLE JUAN ANTONIO CABESTANY - Aprox. Calle Júpiter
# ALHAMBRA.- Esquina Carretera Bellasvistas
# CALLE RAMÓN CARANDE - Aprox. C/ San Salvador
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Cueva de la Pileta
# Aproximado Parque Amate
# RONDA CAPUCHINOS - Aprox. C/ Corinto
# CALLE JOSÉ MARÍA MORENO GALVÁN - Aprox. C/ Juan Antonio Cabestany
# Aprox. Avda Los Gavilanes
# PLAZA PILATOS - Aprox. C/ San Esteban
# CALLE SAN JUAN BOSCO - Aprox. C/ Arroyo
# PLAZA CRONISTA - Aprox. C/ Divina Pastora
# MAR DE ALBORÁN - Aprox. Corral de los Olmos
# RONDA DE TRIANA - Aprox. C/ San Vicente de Paul
# PLAZA SAN MARTÍN DE PORRES - Aprox. Avda Alvar Núñez
# PLAZA DEL ZURRAQUE - Aprox. C/ Doc. Jeronimo Pou
# CALLE SAMANIEGO - Aprox. C/ Esperanza de la Trinidad
# AVENIDA SAN FRANCISCO JAVIER - Aprox. C/ Camilo José Cela
# AVENIDA DE ROMA - Puerta de Jerez
# PUERTA DE LA BARQUETA - Aprox. Puente de la Barqueta
# PARLAMENTO - Aprox. C/ Don Fadrique
# CARRETERA DE CARMONA - Aprox. C/ Maestro Solano
# AVENIDA ALCALDE MANUEL DEL VALLE - Aprox. C/ Alejandro Sawa
# CALLE SAN PABLO - Aprox. C/ Bailén
# CALLE DOCTOR LAFFON - Aprox. C/ Tesalonica
# CALLE ALFARERIA - Aprox. Ronda de Triana
# GLORIETA REPUBLICA DOMINICANA - Aprox. C/ López de Gomara
# AVENIDA REINA MERCEDES - Aprox. C/ Profesor García González
# CALLE CIUDAD DE LIRIA - Aprox. Avda de Fernando
# CARRETERA DE CARMONA - Aprox. Avda de Llanes
# CALLE VICTORIA KENT - Aprox. Avda Alcalde Manuel del Valle
# AVENIDA DE MIRAFLORES - Aprox. C/ Albaida
# RONDA TAMARGUILLO - Aprox. Alfonso Laso de la Vega
# AVENIDA CARDENAL BUENO MONREAL - Aprox. C/ Bogota
# CALLE SINAÍ - Aprox. C/ Baltazar Gracián
# AVENIDA KANSAS CITY - Aprox. C/ Baltasar Gracián
# AVENIDA ALCALDE MANUEL DEL VALLE - Aprox. C/ Baltasar de Alcázar
# PARLAMENTO - Aprox. C/ San Juan de Ribera
# GLORIETA SAN DIEGO - Aprox. C/ Palos de la Frontera
# CALLE AMERICO VESPUCIO - Aprox. C/ Gregor Mendel
# PASEO DE EUROPA - Aprox. Ava de Francia
# AVENIDA EDUARDO DATO - Detrás Estadio Sánchez Pizjuan
# AVENIDA KANSAS CITY - Aprox. Hotel Occidental
# AVENIDA EDUARDO DATO - Aprox. Avda de San Francisco Javier
# GRAN PLAZA - Aprox. Calle Marquez de Pickman
# ALAMEDA DE HÉRCULES - Aprox. C/ Vulcano
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Estación de RENFE
# AVENIDA DE LAS CIENCIAS - Aprox. Avda de la Republica China
# CALLE JOSÉ SARAMAGO - Aprox. Avda del Alcalde Juan Fernández
# PLAZA SAN FRANCISCO - Aprox C/ Hernando Colón
# CIUDAD DE CHIVA - Aprox. C/ ciudad de Liria
# GLORIETA DEL PRIMERO DE MAYO - Aprox. C/ Carlos Marx
# PLAZA SAN JUAN DE LA PALMA - Aprox. iglesia
# CALLE RAFAEL SALGADO - Aprox. C/ Castillo Alcala de Guadaira
# RONDA TAMARGUILLO - Plaza Ruperto Chapí
# CALLE PINO MONTANO - Aprox. C/ Estafeta
# CALLE AMÉRICO VESPUCIO - Aprox. C/ Juan Bautista Muñoz
# PLAZA CRISTO DE BURGOS - Pza de San Pedro
# CALLE FLOR DE RETAMA - Aprox. Centro Deportivo Entreflores
# AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Paseo Miguel de Unamuno
# CALLE LUIS MORALES - Aprox. Nervión Plaza
# CALLE VIRGEN DE LA VICTORIA - Aprox. C/ Asunción
# AVENIDA DIEGO MARTINEZ BARRIO - Aprox. Avda Gal Garcia de la Herranz
# CALLE AGRICULTORES - Aprox. C/ estrella Betelgeuse
# PLAZA PUMAREJO - Aprox. Calle San Luis
# CALLE ADRIANO - Aprox. C/ Antonia Díaz
# GASPAR CALDERAS.- Esquina con Carretera Bellasvistas
# AVENIDA REINA MERCEDES - Aprox. Glorieta Alcalde de Parias Merry
# ALCALDE MANUEL DEL VALLE - Aprox. C/ Pino Montano
# CIUDAD DE CHIVA - Aprox. Pza del Árbol Rey
# CALLE DE HERNÁN CORTÉS - Aprox. C/ Eslava
# AVENIDA AERONAUTICA - Aprox. Avda del Deporte
# CALLE URQUIZA - Aprox. C/ Venecia
# CALLE MANUEL SIUROT - Aprox. Hospital Universitario Virgen del Rocio
# PLAZA SAN ANTONIO DE PADUA - Aprox. C/ Marqués de la Mina
# CALLE REYES CATÓLICOS - Aprox. C/ Gravina
# AVENIDA KANSAS CITY - Aprox. Avda El Greco
# CALLE TABLADILLA - Aprox. C/ Cardenal Ilundaín
# ALAMEDA DE HERCULES - Aprox. Calle Peris Mencheta
# PLAZA JERONIMO DE CORDOBA- Aprox. C/ Escuelas Pías
# CALLE VIRGEN DE LUJAN - Aprox. Virgen de la Victoria
# CALLE ENRAMADILLA - Aprox. C/ Barrau
# RONDA DE TRIANA - Aprox. C/ de Manuel Arellano
# PZA FARMACÉUTICO MURILLO HERRERA - Aprox. C/ Pajes de Corro
# AVENIDA HYTASA - Aprox. Nuestra Señora de los Dolores
# RONDA TAMARGUILLO - Aprox. Marqués de Pickman
# CALLE DE MARIA AUXILIADORA - Aprox. C/ Gonzalo de Bilbao
# CALLE GEMA - Aprox. Avda de las Ciencias
# CALLE DOCTOR PEDRO DE CASTRO - Aprox. C/ Doc. Gabriel Sánchez
# AVENIDA DE LA CRUZ ROJA - Aprox. C/ Albaida
# PASEO CATALINA RIBERA - Frente a la Diputación Provincial
# CALLE HINIESTA - Aprox. Convento Santa Isabel
# AVENIDA DE LAS CIENCIAS - Aprox. C/ Flor de Salvia
# CALLE AMADOR DE LOS RIOS - Aprox. C/ Lope de Vega
# CALLE DOCTOR JAIME MARCOS - Aprox. Avda. Doc. Fedriani
# CALLE SAN JUAN DE RIBERA - Aprox. C/ Fray Isidoro de Sevilla
# CALLE DEL INCA GARCILASO - Aprox. C/ Jerónimo de Aguilar
# CALLE FRANCISCO MURILLO - Aprox. C/ Manuel Siurot
# CALLE MUÑOZ LEÓN - Aprox. C/ Morera
# AVENIDA CARDENAL BUENO MONREAL - Aprox. Avda Ramón Carande
# GLORIETA PLUS ULTRA - Aprox. Estadio Manuel Ruiz de Lopera
# AVDA ESPERANZA DE TRIANA - Aprox. Plaza Amadeo Janone
# CALLE VIRGEN DE LUJÁN - Aprox. C/ Asunción
# ESTACIÓN RENFE SANTA JUSTA
# AVENIDA DE LA PALMERA - Aprox. Clinica de Fátima
# AVENIDA CARDENAL BUENO MONREAL - Aprox. Avda Manuel Siurot
# CALLE ALHÓNDIGA - Aprox. Card. Cervantes
# AVENIDA REINA MERCEDES - Aprox. C/ Profesor García González
# CALLE VIRGEN DE LUJÁN - Aprox. Glorieta las Cigarreras
# CALLE ZORZAL - Aprox. Avenida de Andalucia
# AVENIDA SOLEA - Aprox. C/ Media Granaína
# CALLE JOSE DIAZ - Aprox. Avda Concejal Alberto Jiménez-Becerril
# AVENIDA DE ANDALUCIA - Aprox. Entrada TUSSAM
# AVENIDA DE ANDALUCIA - Aprox. Cochera de TUSSAM

# %% [markdown]
# ### ¡Prueba tú!
# El servicio web ofrecido por https://swapi.dev/ proporciona información sobre las películas de la saga Star Wars. Consulta la [documentación del servicio](https://swapi.dev/documentation) y escribe un código similar al de Sevici que muestre los nombres de todos los personajes que aparecen en el episodio VI.

# %%
with urllib.request.urlopen("https://swapi.dev/api/films/6/") as p:
    films_json = p.read()
    personajes = json.loads(films_json)["characters"]
    for url in personajes:
        with urllib.request.urlopen(url) as c:
            char_json = c.read()
            print(json.loads(char_json)["name"])
# Out:
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Owen Lars
# Beru Whitesun lars
# Obi-Wan Kenobi
# Anakin Skywalker
# Wilhuff Tarkin
# Chewbacca
# Yoda
# Palpatine
# Nute Gunray
# Padmé Amidala
# Ayla Secura
# Mace Windu
# Ki-Adi-Mundi
# Kit Fisto
# Eeth Koth
# Adi Gallia
# Saesee Tiin
# Plo Koon
# Poggle the Lesser
# Luminara Unduli
# Dooku
# Bail Prestor Organa
# R4-P17
# Shaak Ti
# Grievous
# Tarfful
# Raymus Antilles
# Sly Moore
# Tion Medon

# %%
import urllib.request
import json
def mostrarEstacion(estacion=""):
    with urllib.request.urlopen("http://api.citybik.es/v2/networks?fields=stations") as f:
        sevici_json = f.read()
        estaciones = json.loads(sevici_json)
        print(estaciones)
# urllib.request.urlopen es parecido a la función open, pero en lugar de leer
# desde un fichero estamos leyendo una dirección http
mostrarEstacion()
# Out:
# {'networks': [{'company': ['ЗАО «СитиБайк»'], 'href': '/v2/networks/velobike-moscow', 'id': 'velobike-moscow', 'location': {'city': 'Moscow', 'country': 'RU', 'latitude': 55.75, 'longitude': 37.616667}, 'name': 'Velobike'}, {'company': ['Gobike A/S'], 'href': '/v2/networks/bycyklen', 'id': 'bycyklen', 'location': {'city': 'Copenhagen', 'country': 'DK', 'latitude': 55.673582, 'longitude': 12.564984}, 'name': 'Bycyklen'}, {'company': ['Gobike A/S'], 'href': '/v2/networks/nu-connect', 'id': 'nu-connect', 'location': {'city': 'Utrecht', 'country': 'NL', 'latitude': 52.117, 'longitude': 5.067}, 'name': 'Nu-Connect'}, {'company': ['Urban Infrastructure Partner'], 'href': '/v2/networks/baerum-bysykkel', 'id': 'baerum-bysykkel', 'location': {'city': 'Bærum', 'country': 'NO', 'latitude': 59.89455, 'longitude': 10.546343}, 'name': 'Bysykkel'}, {'company': ['Gobike A/S'], 'href': '/v2/networks/bysykkelen', 'id': 'bysykkelen', 'location': {'city': 'Stavanger', 'country': 'NO', 'latitude': 58.969975, 'longitude': 5.733107}, 'name': 'Bysykkelen'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-a-rua', 'id': 'onroll-a-rua', 'location': {'city': 'A Rúa', 'country': 'ES', 'latitude': 42.392049, 'longitude': -7.114634}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-albacete', 'id': 'onroll-albacete', 'location': {'city': 'Albacete', 'country': 'ES', 'latitude': 38.98913, 'longitude': -1.858485}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-alhama-de-murcia', 'id': 'onroll-alhama-de-murcia', 'location': {'city': 'Alhama de Murcia', 'country': 'ES', 'latitude': 37.849831, 'longitude': -1.424891}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-almunecar', 'id': 'onroll-almunecar', 'location': {'city': 'Almuñécar', 'country': 'ES', 'latitude': 36.735789, 'longitude': -3.688828}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-antequera', 'id': 'onroll-antequera', 'location': {'city': 'Antequera', 'country': 'ES', 'latitude': 37.018427, 'longitude': -4.563775}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-aranda-de-duero', 'id': 'onroll-aranda-de-duero', 'location': {'city': 'Aranda de Duero', 'country': 'ES', 'latitude': 41.667601, 'longitude': -3.689526}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-aranjuez', 'id': 'onroll-aranjuez', 'location': {'city': 'Aranjuez', 'country': 'ES', 'latitude': 40.03097, 'longitude': -3.605742}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-badajoz', 'id': 'onroll-badajoz', 'location': {'city': 'Badajoz', 'country': 'ES', 'latitude': 38.873627, 'longitude': -6.99451}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-baeza', 'id': 'onroll-baeza', 'location': {'city': 'Baeza', 'country': 'ES', 'latitude': 37.99537, 'longitude': -3.468248}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-benidorm', 'id': 'onroll-benidorm', 'location': {'city': 'Benidorm', 'country': 'ES', 'latitude': 38.541251, 'longitude': -0.126808}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-blanca', 'id': 'onroll-blanca', 'location': {'city': 'Blanca', 'country': 'ES', 'latitude': 38.178195, 'longitude': -1.372402}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-cieza', 'id': 'onroll-cieza', 'location': {'city': 'Cieza', 'country': 'ES', 'latitude': 38.239139, 'longitude': -1.417262}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-don-benito-villanueva', 'id': 'onroll-don-benito-villanueva', 'location': {'city': 'Don Benito - Villanueva', 'country': 'ES', 'latitude': 38.964699, 'longitude': -5.829693}, 'name': 'Onroll'}, {'company': ['Domoblue'], 'href': '/v2/networks/onroll-el-campello', 'id': 'onroll-el-campello', 'location': {'city': 'El Campello', 'country': 'ES', 'latitude': 38.419616, 'longitude': -0.39838 ...
